# %%
-- Upgrade `agp_data`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_data` LIKE `hive_metastore`.`agp_aggregations`.`agp_data` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_data`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_data`');

-- Upgrade `agp_data_bkp`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp` LIKE `hive_metastore`.`agp_aggregations`.`agp_data_bkp` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data_bkp` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp`');

-- Upgrade `agp_data_dec9_ignite`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_dec9_ignite` LIKE `hive_metastore`.`agp_aggregations`.`agp_data_dec9_ignite` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data_dec9_ignite` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_data_dec9_ignite`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_dec9_ignite`');

-- Upgrade `agp_data_ignite_aws_dec_bkp`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_ignite_aws_dec_bkp` LIKE `hive_metastore`.`agp_aggregations`.`agp_data_ignite_aws_dec_bkp` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data_ignite_aws_dec_bkp` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_data_ignite_aws_dec_bkp`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_ignite_aws_dec_bkp`');

-- Upgrade `agp_data_ignite_aws_full_bkp`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_ignite_aws_full_bkp` LIKE `hive_metastore`.`agp_aggregations`.`agp_data_ignite_aws_full_bkp` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data_ignite_aws_full_bkp` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_data_ignite_aws_full_bkp`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_data_ignite_aws_full_bkp`');

-- Upgrade `agp_mapping`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_mapping` LIKE `hive_metastore`.`agp_aggregations`.`agp_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_mapping` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_mapping`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_mapping`');

-- Upgrade `agp_reporting_data`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_data` LIKE `hive_metastore`.`agp_aggregations`.`agp_reporting_data` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_reporting_data` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_data`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_data`');

-- Upgrade `agp_reporting_mapping_demand`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_mapping_demand` LIKE `hive_metastore`.`agp_aggregations`.`agp_reporting_mapping_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_reporting_mapping_demand` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_mapping_demand`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_mapping_demand`');

-- Upgrade `agp_reporting_mapping_supply`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_mapping_supply` LIKE `hive_metastore`.`agp_aggregations`.`agp_reporting_mapping_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_reporting_mapping_supply` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_mapping_supply`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`agp_reporting_mapping_supply`');

-- Upgrade `one_dt_campaign_mapping`
CREATE TABLE `prod_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping` LIKE `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping`');

# %%
-- Upgrade `ignite_event_metrics`
CREATE TABLE `prod_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics` LIKE `hive_metastore`.`anomaly_detection`.`ignite_event_metrics` COPY LOCATION;
ALTER TABLE `hive_metastore`.`anomaly_detection`.`ignite_event_metrics` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics`');

-- Upgrade `ignite_event_statistics`
CREATE TABLE `prod_one_dt_datalake`.`anomaly_detection`.`ignite_event_statistics` LIKE `hive_metastore`.`anomaly_detection`.`ignite_event_statistics` COPY LOCATION;
ALTER TABLE `hive_metastore`.`anomaly_detection`.`ignite_event_statistics` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`anomaly_detection`.`ignite_event_statistics`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`anomaly_detection`.`ignite_event_statistics`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_activations` LIKE `hive_metastore`.`atlas_rawdata`.`dt_activations` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_activations` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_activations`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_activations`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_ad_integration_error_log` LIKE `hive_metastore`.`atlas_rawdata`.`dt_ad_integration_error_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_ad_integration_error_log` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_ad_integration_error_log`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_ad_integration_error_log`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_app`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_tracking` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app_tracking` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app_tracking` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_tracking`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_tracking`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_type` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app_type` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_type`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_type`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app_versions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app_versions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_ad_integration` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_ad_integration` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_ad_integration` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_ad_integration`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_ad_integration`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_app_segments` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_app_segments` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_app_segments` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_app_segments`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_app_segments`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_app_types` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_app_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_app_types` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_app_types`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_app_types`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_apps` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_device_os` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_device_os` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_device_os` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_device_os`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_device_os`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_device_os_ad_integration` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_device_os_ad_integration` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_device_os_ad_integration` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_device_os_ad_integration`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_device_os_ad_integration`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client` LIKE `hive_metastore`.`atlas_rawdata`.`dt_client` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_client` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_client`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_download` LIKE `hive_metastore`.`atlas_rawdata`.`dt_client_download` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_client_download` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_download`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_download`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_sim` LIKE `hive_metastore`.`atlas_rawdata`.`dt_client_sim` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_client_sim` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_sim`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_sim`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_token` LIKE `hive_metastore`.`atlas_rawdata`.`dt_client_token` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_client_token` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_token`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_token`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_tracking` LIKE `hive_metastore`.`atlas_rawdata`.`dt_client_tracking` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_client_tracking` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_tracking`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_client_tracking`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device` LIKE `hive_metastore`.`atlas_rawdata`.`dt_device` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_device` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_device`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_os` LIKE `hive_metastore`.`atlas_rawdata`.`dt_device_os` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_device_os` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_os`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_os`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_report` LIKE `hive_metastore`.`atlas_rawdata`.`dt_device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_device_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_report`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_report_date` LIKE `hive_metastore`.`atlas_rawdata`.`dt_device_report_date` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_device_report_date` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_report_date`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_device_report_date`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_events` LIKE `hive_metastore`.`atlas_rawdata`.`dt_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_events`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_first_seens` LIKE `hive_metastore`.`atlas_rawdata`.`dt_first_seens` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_first_seens` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_first_seens`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_first_seens`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_mcc_mnc` LIKE `hive_metastore`.`atlas_rawdata`.`dt_mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_mcc_mnc`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_network_type` LIKE `hive_metastore`.`atlas_rawdata`.`dt_network_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_network_type` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_network_type`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_network_type`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_post_install_action_type` LIKE `hive_metastore`.`atlas_rawdata`.`dt_post_install_action_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_post_install_action_type` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_post_install_action_type`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_post_install_action_type`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_post_install_actions` LIKE `hive_metastore`.`atlas_rawdata`.`dt_post_install_actions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_post_install_actions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_post_install_actions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_post_install_actions`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process` LIKE `hive_metastore`.`atlas_rawdata`.`dt_process` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_process` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_process`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_device_state` LIKE `hive_metastore`.`atlas_rawdata`.`dt_process_device_state` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_process_device_state` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_device_state`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_device_state`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_events` LIKE `hive_metastore`.`atlas_rawdata`.`dt_process_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_process_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_events`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_fdrs` LIKE `hive_metastore`.`atlas_rawdata`.`dt_process_fdrs` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_process_fdrs` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_fdrs`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_fdrs`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_type` LIKE `hive_metastore`.`atlas_rawdata`.`dt_process_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_process_type` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_type`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_process_type`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_status` LIKE `hive_metastore`.`atlas_rawdata`.`dt_push_status` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_push_status` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_status`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_status`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_transactions` LIKE `hive_metastore`.`atlas_rawdata`.`dt_push_transactions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_push_transactions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_transactions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_transactions`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_transactions_archive` LIKE `hive_metastore`.`atlas_rawdata`.`dt_push_transactions_archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_push_transactions_archive` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_transactions_archive`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_push_transactions_archive`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_tracking` LIKE `hive_metastore`.`atlas_rawdata`.`dt_tracking` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_tracking` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_tracking`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_tracking`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_transactions` LIKE `hive_metastore`.`atlas_rawdata`.`dt_transactions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_transactions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_transactions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_transactions`');

CREATE TABLE `prod_one_dt_datalake`.`atlas_rawdata`.`dt_transactions_events` LIKE `hive_metastore`.`atlas_rawdata`.`dt_transactions_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_transactions_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`atlas_rawdata`.`dt_transactions_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`atlas_rawdata`.`dt_transactions_events`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`block_list` LIKE `hive_metastore`.`dataengineering_sandbox`.`block_list` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`block_list` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`block_list`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`block_list`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_report` LIKE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_report`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_report_v1` LIKE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_report_v1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_report_v1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_report_v1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_report_v1`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_revenue_blend` LIKE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_revenue_blend` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_revenue_blend` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_revenue_blend`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_revenue_blend`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_revenue_blend_v1` LIKE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_revenue_blend_v1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`bronze_device_revenue_blend_v1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_revenue_blend_v1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`bronze_device_revenue_blend_v1`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_aw_ignite_prod` LIKE `hive_metastore`.`dataengineering_sandbox`.`cm_aw_ignite_prod` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`cm_aw_ignite_prod` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_aw_ignite_prod`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_aw_ignite_prod`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_db_ignite_prod` LIKE `hive_metastore`.`dataengineering_sandbox`.`cm_db_ignite_prod` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`cm_db_ignite_prod` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_db_ignite_prod`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_db_ignite_prod`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_fsd_installs_prod` LIKE `hive_metastore`.`dataengineering_sandbox`.`cm_fsd_installs_prod` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`cm_fsd_installs_prod` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_fsd_installs_prod`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_fsd_installs_prod`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_np_ignite_prod` LIKE `hive_metastore`.`dataengineering_sandbox`.`cm_np_ignite_prod` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`cm_np_ignite_prod` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_np_ignite_prod`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_np_ignite_prod`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_np_ignite_test` LIKE `hive_metastore`.`dataengineering_sandbox`.`cm_np_ignite_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`cm_np_ignite_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_np_ignite_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`cm_np_ignite_test`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`dt_direct_reporting_events` LIKE `hive_metastore`.`dataengineering_sandbox`.`dt_direct_reporting_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`dt_direct_reporting_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`dt_direct_reporting_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`dt_direct_reporting_events`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`partner_download_rates` LIKE `hive_metastore`.`dataengineering_sandbox`.`partner_download_rates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`partner_download_rates` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`partner_download_rates`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`partner_download_rates`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`prod_bidshourlyfull_pq_tbd` LIKE `hive_metastore`.`dataengineering_sandbox`.`prod_bidshourlyfull_pq_tbd` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`prod_bidshourlyfull_pq_tbd` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`prod_bidshourlyfull_pq_tbd`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`prod_bidshourlyfull_pq_tbd`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`reporting_events_chk` LIKE `hive_metastore`.`dataengineering_sandbox`.`reporting_events_chk` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`reporting_events_chk` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`reporting_events_chk`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`reporting_events_chk`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`reporting_events_view` LIKE `hive_metastore`.`dataengineering_sandbox`.`reporting_events_view` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`reporting_events_view` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`reporting_events_view`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`reporting_events_view`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`silver_events` LIKE `hive_metastore`.`dataengineering_sandbox`.`silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`silver_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`silver_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`silver_events`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`sim_info_issue_jar2` LIKE `hive_metastore`.`dataengineering_sandbox`.`sim_info_issue_jar2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`sim_info_issue_jar2` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`sim_info_issue_jar2`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`sim_info_issue_jar2`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`siminfo_issue` LIKE `hive_metastore`.`dataengineering_sandbox`.`siminfo_issue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`siminfo_issue` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`siminfo_issue`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`siminfo_issue`');

CREATE TABLE `prod_one_dt_datalake`.`dataengineering_sandbox`.`uevents_reqid_12192023` LIKE `hive_metastore`.`dataengineering_sandbox`.`uevents_reqid_12192023` COPY LOCATION;
ALTER TABLE `hive_metastore`.`dataengineering_sandbox`.`uevents_reqid_12192023` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`dataengineering_sandbox`.`uevents_reqid_12192023`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`dataengineering_sandbox`.`uevents_reqid_12192023`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`datascience`.`bidopt_excluded_dsps` LIKE `hive_metastore`.`datascience`.`bidopt_excluded_dsps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience`.`bidopt_excluded_dsps` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience`.`bidopt_excluded_dsps`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience`.`bidopt_excluded_dsps`');

CREATE TABLE `prod_one_dt_datalake`.`datascience`.`bidopt_excluded_dsps_monitor` LIKE `hive_metastore`.`datascience`.`bidopt_excluded_dsps_monitor` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience`.`bidopt_excluded_dsps_monitor` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience`.`bidopt_excluded_dsps_monitor`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience`.`bidopt_excluded_dsps_monitor`');

CREATE TABLE `prod_one_dt_datalake`.`datascience`.`employee_info_demo` LIKE `hive_metastore`.`datascience`.`employee_info_demo` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience`.`employee_info_demo` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience`.`employee_info_demo`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience`.`employee_info_demo`');

CREATE TABLE `prod_one_dt_datalake`.`datascience`.`gf2_networks_multipliers` LIKE `hive_metastore`.`datascience`.`gf2_networks_multipliers` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience`.`gf2_networks_multipliers` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience`.`gf2_networks_multipliers`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience`.`gf2_networks_multipliers`');

CREATE TABLE `prod_one_dt_datalake`.`datascience`.`top_20_sites` LIKE `hive_metastore`.`datascience`.`top_20_sites` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience`.`top_20_sites` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience`.`top_20_sites`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience`.`top_20_sites`');

CREATE TABLE `prod_one_dt_datalake`.`datascience`.`vertex_ai_poc_features` LIKE `hive_metastore`.`datascience`.`vertex_ai_poc_features` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience`.`vertex_ai_poc_features` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience`.`vertex_ai_poc_features`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience`.`vertex_ai_poc_features`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`datascience_model_performance`.`sdk_bidding` LIKE `hive_metastore`.`datascience_model_performance`.`sdk_bidding` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience_model_performance`.`sdk_bidding` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience_model_performance`.`sdk_bidding`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience_model_performance`.`sdk_bidding`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`datascience_sandbox`.`ods_ranked_tables` LIKE `hive_metastore`.`datascience_sandbox`.`ods_ranked_tables` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience_sandbox`.`ods_ranked_tables` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience_sandbox`.`ods_ranked_tables`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience_sandbox`.`ods_ranked_tables`');

CREATE TABLE `prod_one_dt_datalake`.`datascience_sandbox`.`preloads_installs_df` LIKE `hive_metastore`.`datascience_sandbox`.`preloads_installs_df` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience_sandbox`.`preloads_installs_df` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience_sandbox`.`preloads_installs_df`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience_sandbox`.`preloads_installs_df`');

CREATE TABLE `prod_one_dt_datalake`.`datascience_sandbox`.`site_performance_df` LIKE `hive_metastore`.`datascience_sandbox`.`site_performance_df` COPY LOCATION;
ALTER TABLE `hive_metastore`.`datascience_sandbox`.`site_performance_df` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`datascience_sandbox`.`site_performance_df`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`datascience_sandbox`.`site_performance_df`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`default`.`data_for_michael` LIKE `hive_metastore`.`default`.`data_for_michael` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`data_for_michael` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`data_for_michael`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`data_for_michael`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`demand_loss_diff_table` LIKE `hive_metastore`.`default`.`demand_loss_diff_table` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`demand_loss_diff_table` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`demand_loss_diff_table`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`demand_loss_diff_table`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`floor_price_table_prod` LIKE `hive_metastore`.`default`.`floor_price_table_prod` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`floor_price_table_prod` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`floor_price_table_prod`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`floor_price_table_prod`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`imp_diff_table` LIKE `hive_metastore`.`default`.`imp_diff_table` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`imp_diff_table` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`imp_diff_table`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`imp_diff_table`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`loss_diff_table` LIKE `hive_metastore`.`default`.`loss_diff_table` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`loss_diff_table` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`loss_diff_table`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`loss_diff_table`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`nbr_codes` LIKE `hive_metastore`.`default`.`nbr_codes` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`nbr_codes` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`nbr_codes`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`nbr_codes`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`req_diff_table` LIKE `hive_metastore`.`default`.`req_diff_table` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`req_diff_table` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`req_diff_table`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`req_diff_table`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`staplegames_dup_issue` LIKE `hive_metastore`.`default`.`staplegames_dup_issue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`staplegames_dup_issue` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`staplegames_dup_issue`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`staplegames_dup_issue`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`ttd_nbr_codes` LIKE `hive_metastore`.`default`.`ttd_nbr_codes` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`ttd_nbr_codes` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`ttd_nbr_codes`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`ttd_nbr_codes`');

CREATE TABLE `prod_one_dt_datalake`.`default`.`zero_drop_table` LIKE `hive_metastore`.`default`.`zero_drop_table` COPY LOCATION;
ALTER TABLE `hive_metastore`.`default`.`zero_drop_table` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`default`.`zero_drop_table`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`default`.`zero_drop_table`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_dsps_redirects` LIKE `hive_metastore`.`fyber_bi`.`ad_quality_dsps_redirects` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`ad_quality_dsps_redirects` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`ad_quality_dsps_redirects`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_dsps_redirects`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_redirects_per_publisher` LIKE `hive_metastore`.`fyber_bi`.`ad_quality_redirects_per_publisher` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`ad_quality_redirects_per_publisher` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`ad_quality_redirects_per_publisher`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_redirects_per_publisher`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top25_dsps_redirects` LIKE `hive_metastore`.`fyber_bi`.`ad_quality_top25_dsps_redirects` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`ad_quality_top25_dsps_redirects` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top25_dsps_redirects`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top25_dsps_redirects`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top5_advertiser_domains` LIKE `hive_metastore`.`fyber_bi`.`ad_quality_top5_advertiser_domains` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`ad_quality_top5_advertiser_domains` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top5_advertiser_domains`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top5_advertiser_domains`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top5_creative_ids` LIKE `hive_metastore`.`fyber_bi`.`ad_quality_top5_creative_ids` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`ad_quality_top5_creative_ids` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top5_creative_ids`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`ad_quality_top5_creative_ids`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`adc_dtx_device_data_daily` LIKE `hive_metastore`.`fyber_bi`.`adc_dtx_device_data_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`adc_dtx_device_data_daily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`adc_dtx_device_data_daily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`adc_dtx_device_data_daily`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`app_apps_daily` LIKE `hive_metastore`.`fyber_bi`.`app_apps_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_apps_daily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`app_apps_daily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`app_apps_daily`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`app_apps_monthly` LIKE `hive_metastore`.`fyber_bi`.`app_apps_monthly` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_apps_monthly` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`app_apps_monthly`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`app_apps_monthly`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`app_fraud_data` LIKE `hive_metastore`.`fyber_bi`.`app_fraud_data` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_fraud_data` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`app_fraud_data`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`app_fraud_data`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`apps_monthly` LIKE `hive_metastore`.`fyber_bi`.`apps_monthly` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`apps_monthly` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`apps_monthly`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`apps_monthly`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`archive` LIKE `hive_metastore`.`fyber_bi`.`archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`archive` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`archive`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`archive`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`fyberdaily` LIKE `hive_metastore`.`fyber_bi`.`fyberdaily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`fyberdaily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`fyberdaily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`fyberdaily`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_demand_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_demand_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_demand_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_demand_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_demand_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_personal_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_personal_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_personal_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_personal_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_personal_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_supply_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_supply_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_supply_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`marketplace_demand_hourly` LIKE `hive_metastore`.`fyber_bi`.`marketplace_demand_hourly` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`marketplace_demand_hourly` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`marketplace_demand_hourly`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`marketplace_demand_hourly`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`med_mediation_daily` LIKE `hive_metastore`.`fyber_bi`.`med_mediation_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`med_mediation_daily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`med_mediation_daily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`med_mediation_daily`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive` LIKE `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`prd_fairbid` LIKE `hive_metastore`.`fyber_bi`.`prd_fairbid` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_fairbid` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`prd_fairbid`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`prd_fairbid`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand` LIKE `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply` LIKE `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`prd_offerwall` LIKE `hive_metastore`.`fyber_bi`.`prd_offerwall` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_offerwall` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`prd_offerwall`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`prd_offerwall`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand` LIKE `hive_metastore`.`fyber_bi`.`revenue_overtime_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`revenue_overtime_demand` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply` LIKE `hive_metastore`.`fyber_bi`.`revenue_overtime_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`revenue_overtime_supply` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi`.`sdk_report` LIKE `hive_metastore`.`fyber_bi`.`sdk_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`sdk_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi`.`sdk_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi`.`sdk_report`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`ad_formats` LIKE `hive_metastore`.`fyber_bi_utils`.`ad_formats` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`ad_formats` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`ad_formats`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`ad_formats`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`appsinfo` LIKE `hive_metastore`.`fyber_bi_utils`.`appsinfo` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`appsinfo` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`appsinfo`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`appsinfo`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_campaign_info_salesforce` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_campaign_info_salesforce` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_campaign_info_salesforce` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_campaign_info_salesforce`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_campaign_info_salesforce`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_campaign_info_salesforce_test` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_campaign_info_salesforce_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_campaign_info_salesforce_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_campaign_info_salesforce_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_campaign_info_salesforce_test`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_contract_salesforce` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_contract_salesforce` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_contract_salesforce` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_contract_salesforce`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_contract_salesforce`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_contract_salesforce_test` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_contract_salesforce_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_contract_salesforce_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_contract_salesforce_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_contract_salesforce_test`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_opportunity_salesforce` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_opportunity_salesforce` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_opportunity_salesforce` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_opportunity_salesforce`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_opportunity_salesforce`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_opportunity_salesforce_test` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_opportunity_salesforce_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_opportunity_salesforce_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_opportunity_salesforce_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_opportunity_salesforce_test`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_test` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_test`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_unified` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce_unified` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce_unified` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_unified`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_unified`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_unified_test` LIKE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce_unified_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`brand_salesforce_unified_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_unified_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`brand_salesforce_unified_test`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`creative_types` LIKE `hive_metastore`.`fyber_bi_utils`.`creative_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`creative_types` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`creative_types`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`creative_types`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`dates` LIKE `hive_metastore`.`fyber_bi_utils`.`dates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`dates` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`dates`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`dates`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`deals_mapping` LIKE `hive_metastore`.`fyber_bi_utils`.`deals_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`deals_mapping` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`deals_mapping`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`deals_mapping`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities` LIKE `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`demand_start_dates_from_csv` LIKE `hive_metastore`.`fyber_bi_utils`.`demand_start_dates_from_csv` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`demand_start_dates_from_csv` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`demand_start_dates_from_csv`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`demand_start_dates_from_csv`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`dt_appreciate_salesforce` LIKE `hive_metastore`.`fyber_bi_utils`.`dt_appreciate_salesforce` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`dt_appreciate_salesforce` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`dt_appreciate_salesforce`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`dt_appreciate_salesforce`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`dt_salesforce` LIKE `hive_metastore`.`fyber_bi_utils`.`dt_salesforce` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`dt_salesforce` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`dt_salesforce`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`dt_salesforce`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`employee_list` LIKE `hive_metastore`.`fyber_bi_utils`.`employee_list` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`employee_list` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`employee_list`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`employee_list`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` LIKE `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map` LIKE `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats` LIKE `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`placement_types` LIKE `hive_metastore`.`fyber_bi_utils`.`placement_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`placement_types` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`placement_types`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`placement_types`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand` LIKE `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply` LIKE `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`sf_demand` LIKE `hive_metastore`.`fyber_bi_utils`.`sf_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`sf_demand` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`sf_demand`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`sf_demand`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`sf_supply` LIKE `hive_metastore`.`fyber_bi_utils`.`sf_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`sf_supply` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`sf_supply`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`sf_supply`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_demand` LIKE `hive_metastore`.`fyber_bi_utils`.`start_date_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`start_date_demand` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_demand`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_demand`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation` LIKE `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_supply` LIKE `hive_metastore`.`fyber_bi_utils`.`start_date_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`start_date_supply` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_supply`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`start_date_supply`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities` LIKE `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_bi_utils`.`supply_start_dates_from_csv` LIKE `hive_metastore`.`fyber_bi_utils`.`supply_start_dates_from_csv` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`supply_start_dates_from_csv` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_bi_utils`.`supply_start_dates_from_csv`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_bi_utils`.`supply_start_dates_from_csv`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`fyber_billing`.`marketplace` LIKE `hive_metastore`.`fyber_billing`.`marketplace` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`marketplace` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_billing`.`marketplace`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_billing`.`marketplace`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_billing`.`marketplace_vw` LIKE `hive_metastore`.`fyber_billing`.`marketplace_vw` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`marketplace_vw` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_billing`.`marketplace_vw`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_billing`.`marketplace_vw`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2` LIKE `hive_metastore`.`fyber_billing`.`mpl_archive_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`mpl_archive_v2` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_billing`.`offerwall` LIKE `hive_metastore`.`fyber_billing`.`offerwall` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`offerwall` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_billing`.`offerwall`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_billing`.`offerwall`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_billing`.`offerwall_vw` LIKE `hive_metastore`.`fyber_billing`.`offerwall_vw` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`offerwall_vw` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_billing`.`offerwall_vw`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_billing`.`offerwall_vw`');

CREATE TABLE `prod_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2` LIKE `hive_metastore`.`fyber_billing`.`ofw_archive_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`ofw_archive_v2` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`aaid_daily` LIKE `hive_metastore`.`lakehouse`.`aaid_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`aaid_daily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`aaid_daily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`aaid_daily`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa` LIKE `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`app_dimension` LIKE `hive_metastore`.`lakehouse`.`app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`app_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`app_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`audgraph_campaignactivity` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaignactivity` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaignactivity` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`audgraph_campaignactivity`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`audgraph_campaignactivity`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaignflow` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaignflow` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`audience_facets_cache` LIKE `hive_metastore`.`lakehouse`.`audience_facets_cache` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audience_facets_cache` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`audience_facets_cache`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`audience_facets_cache`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bid_campaign_ecr` LIKE `hive_metastore`.`lakehouse`.`bid_campaign_ecr` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bid_campaign_ecr` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bid_campaign_ecr`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bid_campaign_ecr`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bidrate` LIKE `hive_metastore`.`lakehouse`.`bidrate` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bidrate` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bidrate`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bidrate`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_campaign` LIKE `hive_metastore`.`lakehouse`.`bronze_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_campaign` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_campaign`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_campaign`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_campaign_optimization` LIKE `hive_metastore`.`lakehouse`.`bronze_campaign_optimization` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_campaign_optimization` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_campaign_optimization`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_campaign_optimization`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal` LIKE `hive_metastore`.`lakehouse`.`bronze_mcs_signal` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_mcs_signal` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_notification` LIKE `hive_metastore`.`lakehouse`.`bronze_notification` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_notification` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_notification`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_notification`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_pie` LIKE `hive_metastore`.`lakehouse`.`bronze_pie` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_pie` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_pie`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_pie`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_preloads_all` LIKE `hive_metastore`.`lakehouse`.`bronze_preloads_all` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_preloads_all` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_preloads_all`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_preloads_all`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign` LIKE `hive_metastore`.`lakehouse`.`bronze_sti_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_sti_campaign` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign_backup` LIKE `hive_metastore`.`lakehouse`.`bronze_sti_campaign_backup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_sti_campaign_backup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign_backup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign_backup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`campaign_postback` LIKE `hive_metastore`.`lakehouse`.`campaign_postback` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`campaign_postback` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`campaign_postback`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`campaign_postback`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`credit_events` LIKE `hive_metastore`.`lakehouse`.`credit_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`credit_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`credit_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`credit_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`device_profile` LIKE `hive_metastore`.`lakehouse`.`device_profile` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`device_profile` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`device_profile`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`device_profile`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`device_profile_test` LIKE `hive_metastore`.`lakehouse`.`device_profile_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`device_profile_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`device_profile_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`device_profile_test`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log` LIKE `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent` LIKE `hive_metastore`.`lakehouse`.`invalid_pie_userevent` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`invalid_pie_userevent` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`invalid_silver_events` LIKE `hive_metastore`.`lakehouse`.`invalid_silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`invalid_silver_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`invalid_silver_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`invalid_silver_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`partial_payloads_daily` LIKE `hive_metastore`.`lakehouse`.`partial_payloads_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`partial_payloads_daily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`partial_payloads_daily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`partial_payloads_daily`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v2` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v2` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v2`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v2`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v4` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v4` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v4` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v4`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v4`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v5` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v5` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v5` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v5`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`referrer_cache_v5`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`sequestered_campaign` LIKE `hive_metastore`.`lakehouse`.`sequestered_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`sequestered_campaign` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`sequestered_campaign`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`sequestered_campaign`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`silver_events` LIKE `hive_metastore`.`lakehouse`.`silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`silver_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`silver_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`silver_sti_campaign` LIKE `hive_metastore`.`lakehouse`.`silver_sti_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_sti_campaign` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`silver_sti_campaign`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`silver_sti_campaign`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`silver_sti_campaign_bkp0925` LIKE `hive_metastore`.`lakehouse`.`silver_sti_campaign_bkp0925` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_sti_campaign_bkp0925` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`silver_sti_campaign_bkp0925`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`silver_sti_campaign_bkp0925`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`sti_rate` LIKE `hive_metastore`.`lakehouse`.`sti_rate` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`sti_rate` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`sti_rate`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`sti_rate`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_activity` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_activity` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`uevents_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`uevents_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_postbackevents` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackevents` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_postbackevents`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_postbackevents`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackfailures` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackfailures` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures_bkp0926` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackfailures_bkp0926` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackfailures_bkp0926` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures_bkp0926`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures_bkp0926`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_reclickevents` LIKE `hive_metastore`.`lakehouse`.`uevents_reclickevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_reclickevents` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_reclickevents`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_reclickevents`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`uevents_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse`.`uevents_us_west_1` LIKE `hive_metastore`.`lakehouse`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse`.`uevents_us_west_1`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`account_manager_mapping_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`account_manager_mapping_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`account_manager_mapping_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`account_manager_mapping_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`account_manager_mapping_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_placements` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_placements` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`advertiser_revshare_override_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`advertiser_revshare_override_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`advertiser_revshare_override_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`advertiser_revshare_override_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`advertiser_revshare_override_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`app` LIKE `hive_metastore`.`lakehouse_dimensions`.`app` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`app` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`app`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`app`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`app_versions` LIKE `hive_metastore`.`lakehouse_dimensions`.`app_versions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`app_versions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`app_versions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`app_versions`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition` LIKE `hive_metastore`.`lakehouse_dimensions`.`audience_definition` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`audience_definition` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_device_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_device_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_download_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_download_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_ad_integration` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_ad_integration` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_ad_integration` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_ad_integration`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_ad_integration`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_apps` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_apps` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_apps`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_apps`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_config` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_config` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_config` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_config`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_config`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_config_value` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_config_value` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_config_value` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_config_value`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_config_value`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_device_os` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_device_os` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_device_os` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_device_os`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_device_os`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_device_os_ad_integration` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_device_os_ad_integration` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_device_os_ad_integration` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_device_os_ad_integration`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_device_os_ad_integration`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`category_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`category_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`client` LIKE `hive_metastore`.`lakehouse_dimensions`.`client` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`client`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`client`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`client_config` LIKE `hive_metastore`.`lakehouse_dimensions`.`client_config` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client_config` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`client_config`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`client_config`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking` LIKE `hive_metastore`.`lakehouse_dimensions`.`client_tracking` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client_tracking` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`country_code_region` LIKE `hive_metastore`.`lakehouse_dimensions`.`country_code_region` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`country_code_region` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`country_code_region`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`country_code_region`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`country_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`country_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`dataai_category` LIKE `hive_metastore`.`lakehouse_dimensions`.`dataai_category` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`dataai_category` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`dataai_category`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`dataai_category`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`dataai_product` LIKE `hive_metastore`.`lakehouse_dimensions`.`dataai_product` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`dataai_product` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`dataai_product`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`dataai_product`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_slot` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_slot` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_slot` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_slot`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_slot`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_tier_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_tier_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_tier_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_tier_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_tier_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin` LIKE `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`events` LIKE `hive_metastore`.`lakehouse_dimensions`.`events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit` LIKE `hive_metastore`.`lakehouse_dimensions`.`experiments_audit` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`experiments_audit` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`fdr_configs` LIKE `hive_metastore`.`lakehouse_dimensions`.`fdr_configs` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`fdr_configs` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`fdr_configs`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`fdr_configs`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`flow_configs` LIKE `hive_metastore`.`lakehouse_dimensions`.`flow_configs` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`flow_configs` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`flow_configs`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`flow_configs`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`flow_type` LIKE `hive_metastore`.`lakehouse_dimensions`.`flow_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`flow_type` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`flow_type`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`flow_type`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`flows` LIKE `hive_metastore`.`lakehouse_dimensions`.`flows` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`flows` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`flows`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`flows`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows` LIKE `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`location_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`location_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind` LIKE `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_information_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_information_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category` LIKE `hive_metastore`.`lakehouse_dimensions`.`ppd_category` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ppd_category` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`process` LIKE `hive_metastore`.`lakehouse_dimensions`.`process` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`process`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`process`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`process_events` LIKE `hive_metastore`.`lakehouse_dimensions`.`process_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`process_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`process_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`process_events_dtid` LIKE `hive_metastore`.`lakehouse_dimensions`.`process_events_dtid` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process_events_dtid` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`process_events_dtid`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`process_events_dtid`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs` LIKE `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`property_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`property_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`push_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`push_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`push_success_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`push_success_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`rawdata_campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`rawdata_campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`rs_carrier` LIKE `hive_metastore`.`lakehouse_dimensions`.`rs_carrier` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`rs_carrier` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`rs_carrier`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`rs_carrier`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`site_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`site_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`transactions` LIKE `hive_metastore`.`lakehouse_dimensions`.`transactions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`transactions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`transactions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`transactions`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events` LIKE `hive_metastore`.`lakehouse_dimensions`.`transactions_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`transactions_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension`');

# %%
CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`active_device_base` LIKE `hive_metastore`.`lakehouse_reporting`.`active_device_base` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`active_device_base` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`active_device_base`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`active_device_base`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`active_device_base_08182023` LIKE `hive_metastore`.`lakehouse_reporting`.`active_device_base_08182023` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`active_device_base_08182023` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`active_device_base_08182023`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`active_device_base_08182023`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements` LIKE `hive_metastore`.`lakehouse_reporting`.`ad_integration_placements` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`ad_integration_placements` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi` LIKE `hive_metastore`.`lakehouse_reporting`.`aggregated_kpi` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`aggregated_kpi` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue` LIKE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue_hist` LIKE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue_hist` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue_hist` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue_hist`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue_hist`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue_view` LIKE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue_view` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue_view` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue_view`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue_view`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads` LIKE `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_setup_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_setup_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_update_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_update_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_site_optimization_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_site_optimization_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_target_group_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_target_group_event` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`bi_pia_conversion_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`bi_pia_conversion_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`bi_pia_conversion_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`bi_pia_conversion_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`bi_pia_conversion_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`click_replay_log` LIKE `hive_metastore`.`lakehouse_reporting`.`click_replay_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`click_replay_log` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`click_replay_log`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`click_replay_log`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`credit_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`credit_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`daily_aggregated_uevents` LIKE `hive_metastore`.`lakehouse_reporting`.`daily_aggregated_uevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`daily_aggregated_uevents` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`daily_aggregated_uevents`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`daily_aggregated_uevents`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_app_iq` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_app_iq` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_app_iq` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_app_iq`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_app_iq`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_app_performance` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_app_performance` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_app_performance` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_app_performance`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_app_performance`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_appiq` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_dim_appiq` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_dim_appiq` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_appiq`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_appiq`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_company_apps` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_dim_company_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_dim_company_apps` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_company_apps`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_company_apps`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_gameiq` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_dim_gameiq` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_dim_gameiq` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_gameiq`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_dim_gameiq`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_download_revenue` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_download_revenue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_download_revenue` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_download_revenue`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_download_revenue`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_game_iq` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_game_iq` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_game_iq` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_game_iq`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_game_iq`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_metadata` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_metadata` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_metadata` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_metadata`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_metadata`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_rankings` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_rankings` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_rankings` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_rankings`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_rankings`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_retentions` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_retentions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_retentions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_retentions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_retentions`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_usage` LIKE `hive_metastore`.`lakehouse_reporting`.`dataai_usage` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dataai_usage` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_usage`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dataai_usage`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`device_app_timelines` LIKE `hive_metastore`.`lakehouse_reporting`.`device_app_timelines` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_app_timelines` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`device_app_timelines`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`device_app_timelines`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`device_history` LIKE `hive_metastore`.`lakehouse_reporting`.`device_history` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_history` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`device_history`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`device_history`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report` LIKE `hive_metastore`.`lakehouse_reporting`.`device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`device_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_enterprise` LIKE `hive_metastore`.`lakehouse_reporting`.`device_report_enterprise` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_report_enterprise` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_enterprise`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_enterprise`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_flows` LIKE `hive_metastore`.`lakehouse_reporting`.`device_report_flows` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_report_flows` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_flows`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_flows`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_test` LIKE `hive_metastore`.`lakehouse_reporting`.`device_report_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_report_test` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_test`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`device_report_test`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`discovery_notifications_dimension` LIKE `hive_metastore`.`lakehouse_reporting`.`discovery_notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`discovery_notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`discovery_notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`discovery_notifications_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report` LIKE `hive_metastore`.`lakehouse_reporting`.`dt_device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dt_device_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dt_direct_reporting_events` LIKE `hive_metastore`.`lakehouse_reporting`.`dt_direct_reporting_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dt_direct_reporting_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dt_direct_reporting_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dt_direct_reporting_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions` LIKE `hive_metastore`.`lakehouse_reporting`.`dt_samsung_regions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dt_samsung_regions` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended` LIKE `hive_metastore`.`lakehouse_reporting`.`event_data_blended` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_data_blended` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`event_lta` LIKE `hive_metastore`.`lakehouse_reporting`.`event_lta` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_lta` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`event_lta`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`event_lta`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates` LIKE `hive_metastore`.`lakehouse_reporting`.`exchange_rates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`exchange_rates` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`fiscal_calendar` LIKE `hive_metastore`.`lakehouse_reporting`.`fiscal_calendar` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`fiscal_calendar` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`fiscal_calendar`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`fiscal_calendar`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`fota_config` LIKE `hive_metastore`.`lakehouse_reporting`.`fota_config` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`fota_config` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`fota_config`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`fota_config`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`hourly_aggregated_uevents` LIKE `hive_metastore`.`lakehouse_reporting`.`hourly_aggregated_uevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`hourly_aggregated_uevents` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`hourly_aggregated_uevents`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`hourly_aggregated_uevents`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`hub_iap_events` LIKE `hive_metastore`.`lakehouse_reporting`.`hub_iap_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`hub_iap_events` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`hub_iap_events`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`hub_iap_events`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence` LIKE `hive_metastore`.`lakehouse_reporting`.`install_intelligence` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`install_intelligence` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`lakehouse_device_report` LIKE `hive_metastore`.`lakehouse_reporting`.`lakehouse_device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lakehouse_device_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`lakehouse_device_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`lakehouse_device_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`legacy_device_mapping` LIKE `hive_metastore`.`lakehouse_reporting`.`legacy_device_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`legacy_device_mapping` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`legacy_device_mapping`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`legacy_device_mapping`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_ifa` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_ifa` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_ifa` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_ifa`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_ifa`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_control` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_control` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_treatment` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_treatment` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_control` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_control` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_treatment` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_treatment` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`motorola_export` LIKE `hive_metastore`.`lakehouse_reporting`.`motorola_export` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`motorola_export` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`motorola_export`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`motorola_export`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_health_report` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_health_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_health_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`notification_health_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_health_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_report` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`outdated_apk_devices` LIKE `hive_metastore`.`lakehouse_reporting`.`outdated_apk_devices` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`outdated_apk_devices` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`outdated_apk_devices`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`outdated_apk_devices`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates` LIKE `hive_metastore`.`lakehouse_reporting`.`partner_download_rates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`partner_download_rates` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude` LIKE `hive_metastore`.`lakehouse_reporting`.`partner_exclude` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`partner_exclude` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`pia_conversion_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`pia_conversion_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`pia_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`pia_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery` LIKE `hive_metastore`.`lakehouse_reporting`.`preload_recovery` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`preload_recovery` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log` LIKE `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension` LIKE `hive_metastore`.`lakehouse_reporting`.`revenue_shares_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`revenue_shares_dimension` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_getads` LIKE `hive_metastore`.`lakehouse_reporting`.`scorecard_getads` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`scorecard_getads` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_getads`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_getads`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_monetized` LIKE `hive_metastore`.`lakehouse_reporting`.`scorecard_monetized` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`scorecard_monetized` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_monetized`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_monetized`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_process` LIKE `hive_metastore`.`lakehouse_reporting`.`scorecard_process` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`scorecard_process` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_process`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`scorecard_process`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_first_of_day` LIKE `hive_metastore`.`lakehouse_reporting`.`smart_folders_first_of_day` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`smart_folders_first_of_day` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_first_of_day`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_first_of_day`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_first_of_firsts` LIKE `hive_metastore`.`lakehouse_reporting`.`smart_folders_first_of_firsts` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`smart_folders_first_of_firsts` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_first_of_firsts`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_first_of_firsts`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_history` LIKE `hive_metastore`.`lakehouse_reporting`.`smart_folders_history` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`smart_folders_history` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_history`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`smart_folders_history`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report` LIKE `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_daily` LIKE `hive_metastore`.`lakehouse_reporting`.`sti_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`sti_daily` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`sti_daily`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_daily`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`sti_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`sti_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting` LIKE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`template_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`template_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`template_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`template_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`template_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report` LIKE `hive_metastore`.`lakehouse_reporting`.`tripledot_dt_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`tripledot_dt_report` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`user_apps` LIKE `hive_metastore`.`lakehouse_reporting`.`user_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`user_apps` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`user_apps`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`user_apps`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`user_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`user_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`vzw_enterprise_devices` LIKE `hive_metastore`.`lakehouse_reporting`.`vzw_enterprise_devices` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`vzw_enterprise_devices` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`vzw_enterprise_devices`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`vzw_enterprise_devices`');

CREATE TABLE `prod_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library` LIKE `hive_metastore`.`lakehouse_reporting`.`vzw_imei_data_library` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`vzw_imei_data_library` SET TBLPROPERTIES ('upgraded_to' = '`prod_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library`', 'comment' = 'This table is deprecated. Please update to use `prod_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library`');
