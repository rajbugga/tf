# %%
-- Upgrade `hive_metastore`.`agp_aggregations`.`agp_data_bkp` to `dev_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp`
CREATE TABLE `dev_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp` LIKE `hive_metastore`.`agp_aggregations`.`agp_data_bkp` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data_bkp` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp` instead of `hive_metastore`.`agp_aggregations`.`agp_data_bkp`');

-- Upgrade `hive_metastore`.`agp_aggregations`.`agp_mapping` to `dev_one_dt_datalake`.`agp_aggregations`.`agp_mapping`
CREATE TABLE `dev_one_dt_datalake`.`agp_aggregations`.`agp_mapping` LIKE `hive_metastore`.`agp_aggregations`.`agp_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_mapping` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`agp_aggregations`.`agp_mapping`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`agp_aggregations`.`agp_mapping` instead of `hive_metastore`.`agp_aggregations`.`agp_mapping`');

-- Upgrade `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` to `dev_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping`
CREATE TABLE `dev_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping` LIKE `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping` instead of `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping`');

# %%
-- Upgrade `hive_metastore`.`anomaly_detection`.`ignite_event_metrics` to `dev_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics`
CREATE TABLE `dev_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics` LIKE `hive_metastore`.`anomaly_detection`.`ignite_event_metrics` COPY LOCATION;
ALTER TABLE `hive_metastore`.`anomaly_detection`.`ignite_event_metrics` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`anomaly_detection`.`ignite_event_metrics` instead of `hive_metastore`.`anomaly_detection`.`ignite_event_metrics`');

# %%
-- Upgrade `hive_metastore`.`atlas_rawdata`.`audit_table` to `dev_one_dt_datalake`.`atlas_rawdata`.`audit_table`
CREATE TABLE `dev_one_dt_datalake`.`atlas_rawdata`.`audit_table` LIKE `hive_metastore`.`atlas_rawdata`.`audit_table` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`audit_table` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`atlas_rawdata`.`audit_table`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`atlas_rawdata`.`audit_table` instead of `hive_metastore`.`atlas_rawdata`.`audit_table`');

-- Upgrade `hive_metastore`.`atlas_rawdata`.`dt_app` to `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app`
CREATE TABLE `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`atlas_rawdata`.`dt_app`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app` instead of `hive_metastore`.`atlas_rawdata`.`dt_app`');

-- Upgrade `hive_metastore`.`atlas_rawdata`.`dt_app_type` to `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_type`
CREATE TABLE `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_type` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app_type` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_type`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_type` instead of `hive_metastore`.`atlas_rawdata`.`dt_app_type`');

-- Upgrade `hive_metastore`.`atlas_rawdata`.`dt_app_versions` to `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions`
CREATE TABLE `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions` LIKE `hive_metastore`.`atlas_rawdata`.`dt_app_versions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_app_versions` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`atlas_rawdata`.`dt_app_versions` instead of `hive_metastore`.`atlas_rawdata`.`dt_app_versions`');

-- Upgrade `hive_metastore`.`atlas_rawdata`.`dt_carrier_apps` to `dev_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps`
CREATE TABLE `dev_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps` LIKE `hive_metastore`.`atlas_rawdata`.`dt_carrier_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`atlas_rawdata`.`dt_carrier_apps` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`atlas_rawdata`.`dt_carrier_apps` instead of `hive_metastore`.`atlas_rawdata`.`dt_carrier_apps`');

# %%
-- Upgrade `hive_metastore`.`enterprise_automation`.`uevents_us_west_1` to `dev_one_dt_datalake`.`enterprise_automation`.`uevents_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`enterprise_automation`.`uevents_us_west_1` LIKE `hive_metastore`.`enterprise_automation`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`enterprise_automation`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`enterprise_automation`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`enterprise_automation`.`uevents_us_west_1` instead of `hive_metastore`.`enterprise_automation`.`uevents_us_west_1`');

# %%
-- Upgrade `hive_metastore`.`fyber_bi`.`app_apps_daily` to `dev_one_dt_datalake`.`fyber_bi`.`app_apps_daily`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`app_apps_daily` LIKE `hive_metastore`.`fyber_bi`.`app_apps_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_apps_daily` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`app_apps_daily`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`app_apps_daily` instead of `hive_metastore`.`fyber_bi`.`app_apps_daily`');

-- Upgrade `hive_metastore`.`fyber_bi`.`app_apps_monthly` to `dev_one_dt_datalake`.`fyber_bi`.`app_apps_monthly`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`app_apps_monthly` LIKE `hive_metastore`.`fyber_bi`.`app_apps_monthly` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_apps_monthly` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`app_apps_monthly`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`app_apps_monthly` instead of `hive_metastore`.`fyber_bi`.`app_apps_monthly`');

-- Upgrade `hive_metastore`.`fyber_bi`.`app_fraud_data` to `dev_one_dt_datalake`.`fyber_bi`.`app_fraud_data`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`app_fraud_data` LIKE `hive_metastore`.`fyber_bi`.`app_fraud_data` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_fraud_data` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`app_fraud_data`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`app_fraud_data` instead of `hive_metastore`.`fyber_bi`.`app_fraud_data`');

-- Upgrade `hive_metastore`.`fyber_bi`.`archive` to `dev_one_dt_datalake`.`fyber_bi`.`archive`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`archive` LIKE `hive_metastore`.`fyber_bi`.`archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`archive` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`archive`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`archive` instead of `hive_metastore`.`fyber_bi`.`archive`');

-- Upgrade `hive_metastore`.`fyber_bi`.`fyberdaily` to `dev_one_dt_datalake`.`fyber_bi`.`fyberdaily`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`fyberdaily` LIKE `hive_metastore`.`fyber_bi`.`fyberdaily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`fyberdaily` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`fyberdaily`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`fyberdaily` instead of `hive_metastore`.`fyber_bi`.`fyberdaily`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_demand_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_demand_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_demand_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_demand_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_demand_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_demand_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_demand_goals` instead of `hive_metastore`.`fyber_bi`.`gls_demand_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals` instead of `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_personal_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_personal_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_personal_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_personal_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_personal_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_personal_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_personal_goals` instead of `hive_metastore`.`fyber_bi`.`gls_personal_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_supply_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_supply_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_goals` instead of `hive_metastore`.`fyber_bi`.`gls_supply_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals` instead of `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals` instead of `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals` instead of `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` to `dev_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals` instead of `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`med_mediation_daily` to `dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily` LIKE `hive_metastore`.`fyber_bi`.`med_mediation_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`med_mediation_daily` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily` instead of `hive_metastore`.`fyber_bi`.`med_mediation_daily`');

-- Upgrade `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` to `dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive` LIKE `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive` instead of `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_fairbid` to `dev_one_dt_datalake`.`fyber_bi`.`prd_fairbid`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`prd_fairbid` LIKE `hive_metastore`.`fyber_bi`.`prd_fairbid` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_fairbid` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`prd_fairbid`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`prd_fairbid` instead of `hive_metastore`.`fyber_bi`.`prd_fairbid`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` to `dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand` LIKE `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand` instead of `hive_metastore`.`fyber_bi`.`prd_marketplacedemand`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` to `dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply` LIKE `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply` instead of `hive_metastore`.`fyber_bi`.`prd_marketplacesupply`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_offerwall` to `dev_one_dt_datalake`.`fyber_bi`.`prd_offerwall`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`prd_offerwall` LIKE `hive_metastore`.`fyber_bi`.`prd_offerwall` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_offerwall` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`prd_offerwall`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`prd_offerwall` instead of `hive_metastore`.`fyber_bi`.`prd_offerwall`');

-- Upgrade `hive_metastore`.`fyber_bi`.`revenue_overtime_demand` to `dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand` LIKE `hive_metastore`.`fyber_bi`.`revenue_overtime_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`revenue_overtime_demand` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_demand` instead of `hive_metastore`.`fyber_bi`.`revenue_overtime_demand`');

-- Upgrade `hive_metastore`.`fyber_bi`.`revenue_overtime_supply` to `dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply` LIKE `hive_metastore`.`fyber_bi`.`revenue_overtime_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`revenue_overtime_supply` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`revenue_overtime_supply` instead of `hive_metastore`.`fyber_bi`.`revenue_overtime_supply`');

-- Upgrade `hive_metastore`.`fyber_bi`.`sdk_report` to `dev_one_dt_datalake`.`fyber_bi`.`sdk_report`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi`.`sdk_report` LIKE `hive_metastore`.`fyber_bi`.`sdk_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`sdk_report` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi`.`sdk_report`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi`.`sdk_report` instead of `hive_metastore`.`fyber_bi`.`sdk_report`');

# %%
-- Upgrade `hive_metastore`.`fyber_bi_utils`.`ad_formats` to `dev_one_dt_datalake`.`fyber_bi_utils`.`ad_formats`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`ad_formats` LIKE `hive_metastore`.`fyber_bi_utils`.`ad_formats` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`ad_formats` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`ad_formats`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`ad_formats` instead of `hive_metastore`.`fyber_bi_utils`.`ad_formats`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`creative_types` to `dev_one_dt_datalake`.`fyber_bi_utils`.`creative_types`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`creative_types` LIKE `hive_metastore`.`fyber_bi_utils`.`creative_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`creative_types` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`creative_types`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`creative_types` instead of `hive_metastore`.`fyber_bi_utils`.`creative_types`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`dates` to `dev_one_dt_datalake`.`fyber_bi_utils`.`dates`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`dates` LIKE `hive_metastore`.`fyber_bi_utils`.`dates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`dates` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`dates`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`dates` instead of `hive_metastore`.`fyber_bi_utils`.`dates`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` to `dev_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities` LIKE `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities` instead of `hive_metastore`.`fyber_bi_utils`.`demand_opportunities`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`employee_list` to `dev_one_dt_datalake`.`fyber_bi_utils`.`employee_list`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`employee_list` LIKE `hive_metastore`.`fyber_bi_utils`.`employee_list` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`employee_list` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`employee_list`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`employee_list` instead of `hive_metastore`.`fyber_bi_utils`.`employee_list`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` to `dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` LIKE `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` instead of `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` to `dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map` LIKE `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map` instead of `hive_metastore`.`fyber_bi_utils`.`med_mediation_map`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` to `dev_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats` LIKE `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats` instead of `hive_metastore`.`fyber_bi_utils`.`new_ad_formats`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`placement_types` to `dev_one_dt_datalake`.`fyber_bi_utils`.`placement_types`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`placement_types` LIKE `hive_metastore`.`fyber_bi_utils`.`placement_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`placement_types` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`placement_types`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`placement_types` instead of `hive_metastore`.`fyber_bi_utils`.`placement_types`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` to `dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand` LIKE `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand` instead of `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` to `dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply` LIKE `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply` instead of `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`sf_demand` to `dev_one_dt_datalake`.`fyber_bi_utils`.`sf_demand`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`sf_demand` LIKE `hive_metastore`.`fyber_bi_utils`.`sf_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`sf_demand` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`sf_demand`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`sf_demand` instead of `hive_metastore`.`fyber_bi_utils`.`sf_demand`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`sf_supply` to `dev_one_dt_datalake`.`fyber_bi_utils`.`sf_supply`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`sf_supply` LIKE `hive_metastore`.`fyber_bi_utils`.`sf_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`sf_supply` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`sf_supply`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`sf_supply` instead of `hive_metastore`.`fyber_bi_utils`.`sf_supply`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` to `dev_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation` LIKE `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation` instead of `hive_metastore`.`fyber_bi_utils`.`start_date_mediation`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` to `dev_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities`
CREATE TABLE `dev_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities` LIKE `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities` instead of `hive_metastore`.`fyber_bi_utils`.`supply_opportunities`');

# %%
-- Upgrade `hive_metastore`.`fyber_billing`.`marketplace` to `dev_one_dt_datalake`.`fyber_billing`.`marketplace`
CREATE TABLE `dev_one_dt_datalake`.`fyber_billing`.`marketplace` LIKE `hive_metastore`.`fyber_billing`.`marketplace` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`marketplace` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_billing`.`marketplace`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_billing`.`marketplace` instead of `hive_metastore`.`fyber_billing`.`marketplace`');

-- Upgrade `hive_metastore`.`fyber_billing`.`mpl_archive_v2` to `dev_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2`
CREATE TABLE `dev_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2` LIKE `hive_metastore`.`fyber_billing`.`mpl_archive_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`mpl_archive_v2` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2` instead of `hive_metastore`.`fyber_billing`.`mpl_archive_v2`');

-- Upgrade `hive_metastore`.`fyber_billing`.`offerwall` to `dev_one_dt_datalake`.`fyber_billing`.`offerwall`
CREATE TABLE `dev_one_dt_datalake`.`fyber_billing`.`offerwall` LIKE `hive_metastore`.`fyber_billing`.`offerwall` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`offerwall` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_billing`.`offerwall`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_billing`.`offerwall` instead of `hive_metastore`.`fyber_billing`.`offerwall`');

-- Upgrade `hive_metastore`.`fyber_billing`.`ofw_archive_v2` to `dev_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2`
CREATE TABLE `dev_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2` LIKE `hive_metastore`.`fyber_billing`.`ofw_archive_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`ofw_archive_v2` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2` instead of `hive_metastore`.`fyber_billing`.`ofw_archive_v2`');

# %%
-- Upgrade `hive_metastore`.`joker`.`uevents_us_west_1` to `dev_one_dt_datalake`.`joker`.`uevents_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`joker`.`uevents_us_west_1` LIKE `hive_metastore`.`joker`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`joker`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`joker`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`joker`.`uevents_us_west_1` instead of `hive_metastore`.`joker`.`uevents_us_west_1`');

# %%
-- Upgrade `hive_metastore`.`lakehouse`.`aaid_daily` to `dev_one_dt_datalake`.`lakehouse`.`aaid_daily`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`aaid_daily` LIKE `hive_metastore`.`lakehouse`.`aaid_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`aaid_daily` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`aaid_daily`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`aaid_daily` instead of `hive_metastore`.`lakehouse`.`aaid_daily`');

-- Upgrade `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` to `dev_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa` LIKE `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa` instead of `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa`');

-- Upgrade `hive_metastore`.`lakehouse`.`app_dimension` to `dev_one_dt_datalake`.`lakehouse`.`app_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`app_dimension` LIKE `hive_metastore`.`lakehouse`.`app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`app_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`app_dimension` instead of `hive_metastore`.`lakehouse`.`app_dimension`');

-- Upgrade `hive_metastore`.`lakehouse`.`app_dimension_temp` to `dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp` LIKE `hive_metastore`.`lakehouse`.`app_dimension_temp` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`app_dimension_temp` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp` instead of `hive_metastore`.`lakehouse`.`app_dimension_temp`');

-- Upgrade `hive_metastore`.`lakehouse`.`app_dimension_temp1` to `dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp1` LIKE `hive_metastore`.`lakehouse`.`app_dimension_temp1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`app_dimension_temp1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`app_dimension_temp1` instead of `hive_metastore`.`lakehouse`.`app_dimension_temp1`');

-- Upgrade `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` to `dev_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload` instead of `hive_metastore`.`lakehouse`.`audgraph_campaigndownload`');

-- Upgrade `hive_metastore`.`lakehouse`.`audgraph_campaignflow` to `dev_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaignflow` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaignflow` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow` instead of `hive_metastore`.`lakehouse`.`audgraph_campaignflow`');

-- Upgrade `hive_metastore`.`lakehouse`.`audience_facets_cache` to `dev_one_dt_datalake`.`lakehouse`.`audience_facets_cache`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`audience_facets_cache` LIKE `hive_metastore`.`lakehouse`.`audience_facets_cache` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audience_facets_cache` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`audience_facets_cache`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`audience_facets_cache` instead of `hive_metastore`.`lakehouse`.`audience_facets_cache`');

-- Upgrade `hive_metastore`.`lakehouse`.`bidrate` to `dev_one_dt_datalake`.`lakehouse`.`bidrate`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bidrate` LIKE `hive_metastore`.`lakehouse`.`bidrate` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bidrate` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bidrate`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bidrate` instead of `hive_metastore`.`lakehouse`.`bidrate`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_campaign` to `dev_one_dt_datalake`.`lakehouse`.`bronze_campaign`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bronze_campaign` LIKE `hive_metastore`.`lakehouse`.`bronze_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_campaign` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bronze_campaign`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bronze_campaign` instead of `hive_metastore`.`lakehouse`.`bronze_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_mcs_signal` to `dev_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal` LIKE `hive_metastore`.`lakehouse`.`bronze_mcs_signal` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_mcs_signal` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal` instead of `hive_metastore`.`lakehouse`.`bronze_mcs_signal`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_notification` to `dev_one_dt_datalake`.`lakehouse`.`bronze_notification`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bronze_notification` LIKE `hive_metastore`.`lakehouse`.`bronze_notification` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_notification` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bronze_notification`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bronze_notification` instead of `hive_metastore`.`lakehouse`.`bronze_notification`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_pie` to `dev_one_dt_datalake`.`lakehouse`.`bronze_pie`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bronze_pie` LIKE `hive_metastore`.`lakehouse`.`bronze_pie` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_pie` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bronze_pie`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bronze_pie` instead of `hive_metastore`.`lakehouse`.`bronze_pie`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_preloads_all` to `dev_one_dt_datalake`.`lakehouse`.`bronze_preloads_all`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bronze_preloads_all` LIKE `hive_metastore`.`lakehouse`.`bronze_preloads_all` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_preloads_all` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bronze_preloads_all`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bronze_preloads_all` instead of `hive_metastore`.`lakehouse`.`bronze_preloads_all`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_sti_campaign` to `dev_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign` LIKE `hive_metastore`.`lakehouse`.`bronze_sti_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_sti_campaign` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign` instead of `hive_metastore`.`lakehouse`.`bronze_sti_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`campaign_postback` to `dev_one_dt_datalake`.`lakehouse`.`campaign_postback`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`campaign_postback` LIKE `hive_metastore`.`lakehouse`.`campaign_postback` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`campaign_postback` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`campaign_postback`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`campaign_postback` instead of `hive_metastore`.`lakehouse`.`campaign_postback`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`credit_events` to `dev_one_dt_datalake`.`lakehouse`.`credit_events`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`credit_events` LIKE `hive_metastore`.`lakehouse`.`credit_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`credit_events` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`credit_events`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`credit_events` instead of `hive_metastore`.`lakehouse`.`credit_events`');

-- Upgrade `hive_metastore`.`lakehouse`.`device_profile` to `dev_one_dt_datalake`.`lakehouse`.`device_profile`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`device_profile` LIKE `hive_metastore`.`lakehouse`.`device_profile` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`device_profile` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`device_profile`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`device_profile` instead of `hive_metastore`.`lakehouse`.`device_profile`');

-- Upgrade `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` to `dev_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log` LIKE `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log` instead of `hive_metastore`.`lakehouse`.`dsp_impression_matching_log`');

-- Upgrade `hive_metastore`.`lakehouse`.`invalid_pie_userevent` to `dev_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent` LIKE `hive_metastore`.`lakehouse`.`invalid_pie_userevent` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`invalid_pie_userevent` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent` instead of `hive_metastore`.`lakehouse`.`invalid_pie_userevent`');

-- Upgrade `hive_metastore`.`lakehouse`.`invalid_silver_events` to `dev_one_dt_datalake`.`lakehouse`.`invalid_silver_events`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`invalid_silver_events` LIKE `hive_metastore`.`lakehouse`.`invalid_silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`invalid_silver_events` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`invalid_silver_events`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`invalid_silver_events` instead of `hive_metastore`.`lakehouse`.`invalid_silver_events`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`partial_payloads_daily` to `dev_one_dt_datalake`.`lakehouse`.`partial_payloads_daily`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`partial_payloads_daily` LIKE `hive_metastore`.`lakehouse`.`partial_payloads_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`partial_payloads_daily` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`partial_payloads_daily`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`partial_payloads_daily` instead of `hive_metastore`.`lakehouse`.`partial_payloads_daily`');

-- Upgrade `hive_metastore`.`lakehouse`.`postback_campaign` to `dev_one_dt_datalake`.`lakehouse`.`postback_campaign`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`postback_campaign` LIKE `hive_metastore`.`lakehouse`.`postback_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`postback_campaign` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`postback_campaign`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`postback_campaign` instead of `hive_metastore`.`lakehouse`.`postback_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`referrer_cache_v2` to `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v2`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v2` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v2` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v2`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v2` instead of `hive_metastore`.`lakehouse`.`referrer_cache_v2`');

-- Upgrade `hive_metastore`.`lakehouse`.`referrer_cache_v4` to `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v4`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v4` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v4` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v4` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v4`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v4` instead of `hive_metastore`.`lakehouse`.`referrer_cache_v4`');

-- Upgrade `hive_metastore`.`lakehouse`.`referrer_cache_v5` to `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v5`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v5` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v5` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v5` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v5`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`referrer_cache_v5` instead of `hive_metastore`.`lakehouse`.`referrer_cache_v5`');

-- Upgrade `hive_metastore`.`lakehouse`.`sequestered_campaign` to `dev_one_dt_datalake`.`lakehouse`.`sequestered_campaign`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`sequestered_campaign` LIKE `hive_metastore`.`lakehouse`.`sequestered_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`sequestered_campaign` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`sequestered_campaign`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`sequestered_campaign` instead of `hive_metastore`.`lakehouse`.`sequestered_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`silver_events` to `dev_one_dt_datalake`.`lakehouse`.`silver_events`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`silver_events` LIKE `hive_metastore`.`lakehouse`.`silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_events` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`silver_events`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`silver_events` instead of `hive_metastore`.`lakehouse`.`silver_events`');

-- Upgrade `hive_metastore`.`lakehouse`.`silver_sti_campaign` to `dev_one_dt_datalake`.`lakehouse`.`silver_sti_campaign`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`silver_sti_campaign` LIKE `hive_metastore`.`lakehouse`.`silver_sti_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_sti_campaign` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`silver_sti_campaign`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`silver_sti_campaign` instead of `hive_metastore`.`lakehouse`.`silver_sti_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`tripledot_dt_activity` to `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_activity` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_activity` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity` instead of `hive_metastore`.`lakehouse`.`tripledot_dt_activity`');

-- Upgrade `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` to `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics` instead of `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics`');

-- Upgrade `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` to `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue` instead of `hive_metastore`.`lakehouse`.`tripledot_dt_revenue`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_eu_central_1` to `dev_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`uevents_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1` instead of `hive_metastore`.`lakehouse`.`uevents_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_postbackevents` to `dev_one_dt_datalake`.`lakehouse`.`uevents_postbackevents`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_postbackevents` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackevents` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_postbackevents`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_postbackevents` instead of `hive_metastore`.`lakehouse`.`uevents_postbackevents`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_postbackfailures` to `dev_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackfailures` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackfailures` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures` instead of `hive_metastore`.`lakehouse`.`uevents_postbackfailures`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_reclickevents` to `dev_one_dt_datalake`.`lakehouse`.`uevents_reclickevents`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_reclickevents` LIKE `hive_metastore`.`lakehouse`.`uevents_reclickevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_reclickevents` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_reclickevents`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_reclickevents` instead of `hive_metastore`.`lakehouse`.`uevents_reclickevents`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_sa_east_1` to `dev_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`uevents_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1` instead of `hive_metastore`.`lakehouse`.`uevents_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_us_east_1` to `dev_one_dt_datalake`.`lakehouse`.`uevents_us_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_us_east_1` LIKE `hive_metastore`.`lakehouse`.`uevents_us_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_us_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_us_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_us_east_1` instead of `hive_metastore`.`lakehouse`.`uevents_us_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_us_west_1` to `dev_one_dt_datalake`.`lakehouse`.`uevents_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse`.`uevents_us_west_1` LIKE `hive_metastore`.`lakehouse`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse`.`uevents_us_west_1` instead of `hive_metastore`.`lakehouse`.`uevents_us_west_1`');

# %%
-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log` instead of `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ad_integration_placements` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_placements` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_placements` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_placements` instead of `hive_metastore`.`lakehouse_dimensions`.`ad_integration_placements`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`app_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`app_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`app_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`app_versions` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`app_versions`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`app_versions` LIKE `hive_metastore`.`lakehouse_dimensions`.`app_versions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`app_versions` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`app_versions`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`app_versions` instead of `hive_metastore`.`lakehouse_dimensions`.`app_versions`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`audience_definition` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition` LIKE `hive_metastore`.`lakehouse_dimensions`.`audience_definition` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`audience_definition` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition` instead of `hive_metastore`.`lakehouse_dimensions`.`audience_definition`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`carrier` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier` instead of `hive_metastore`.`lakehouse_dimensions`.`carrier`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc` instead of `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`category_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`category_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`category_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`category_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`client_config` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`client_config`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`client_config` LIKE `hive_metastore`.`lakehouse_dimensions`.`client_config` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client_config` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`client_config`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`client_config` instead of `hive_metastore`.`lakehouse_dimensions`.`client_config`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`country_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`country_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`country_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`country_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`creative_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`device_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_slot` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_slot`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_slot` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_slot` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_slot` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_slot`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_slot` instead of `hive_metastore`.`lakehouse_dimensions`.`device_slot`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin` LIKE `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin` instead of `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`experiments_audit` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit` LIKE `hive_metastore`.`lakehouse_dimensions`.`experiments_audit` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`experiments_audit` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`experiments_audit` instead of `hive_metastore`.`lakehouse_dimensions`.`experiments_audit`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows` LIKE `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows` instead of `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`location_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`location_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`location_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`location_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind` LIKE `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind` instead of `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`partner_app_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_app_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`partner_app_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`partner_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`partner_information_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_information_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_information_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`partner_information_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`partner_information_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`placement_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`platform_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ppd_category` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category` LIKE `hive_metastore`.`lakehouse_dimensions`.`ppd_category` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ppd_category` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category` instead of `hive_metastore`.`lakehouse_dimensions`.`ppd_category`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`process` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`process`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`process` LIKE `hive_metastore`.`lakehouse_dimensions`.`process` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`process`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`process` instead of `hive_metastore`.`lakehouse_dimensions`.`process`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs` LIKE `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs` instead of `hive_metastore`.`lakehouse_dimensions`.`process_fdrs`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`property_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`property_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`property_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`property_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`push_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`push_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`push_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`push_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`rawdata_campaign_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`rawdata_campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`rawdata_campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`rawdata_campaign_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`rawdata_campaign_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`site_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`site_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`site_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`site_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`targets_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`transactions` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions` LIKE `hive_metastore`.`lakehouse_dimensions`.`transactions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`transactions` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions` instead of `hive_metastore`.`lakehouse_dimensions`.`transactions`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`transactions_events` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events` LIKE `hive_metastore`.`lakehouse_dimensions`.`transactions_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`transactions_events` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events` instead of `hive_metastore`.`lakehouse_dimensions`.`transactions_events`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` to `dev_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension`');

# %%
-- Upgrade `hive_metastore`.`lakehouse_reporting`.`active_device_base` to `dev_one_dt_datalake`.`lakehouse_reporting`.`active_device_base`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`active_device_base` LIKE `hive_metastore`.`lakehouse_reporting`.`active_device_base` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`active_device_base` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`active_device_base`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`active_device_base` instead of `hive_metastore`.`lakehouse_reporting`.`active_device_base`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` to `dev_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` to `dev_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact` instead of `hive_metastore`.`lakehouse_reporting`.`advertiser_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`aggregated_kpi` to `dev_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi` LIKE `hive_metastore`.`lakehouse_reporting`.`aggregated_kpi` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`aggregated_kpi` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`aggregated_kpi` instead of `hive_metastore`.`lakehouse_reporting`.`aggregated_kpi`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report` instead of `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance` instead of `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` instead of `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion` instead of `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions` instead of `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe` instead of `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue` to `dev_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue` LIKE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`apps_flyer_ad_revenue` instead of `hive_metastore`.`lakehouse_reporting`.`apps_flyer_ad_revenue`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` to `dev_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads` LIKE `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads` instead of `hive_metastore`.`lakehouse_reporting`.`appwidget_getads`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity` to `dev_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity` LIKE `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity` instead of `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`device_report` to `dev_one_dt_datalake`.`lakehouse_reporting`.`device_report`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`device_report` LIKE `hive_metastore`.`lakehouse_reporting`.`device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`device_report` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`device_report`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`device_report` instead of `hive_metastore`.`lakehouse_reporting`.`device_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`event_fact` to `dev_one_dt_datalake`.`lakehouse_reporting`.`event_fact`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_fact` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`event_fact`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`exchange_rates` to `dev_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates` LIKE `hive_metastore`.`lakehouse_reporting`.`exchange_rates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`exchange_rates` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates` instead of `hive_metastore`.`lakehouse_reporting`.`exchange_rates`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`install_intelligence` to `dev_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence` LIKE `hive_metastore`.`lakehouse_reporting`.`install_intelligence` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`install_intelligence` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence` instead of `hive_metastore`.`lakehouse_reporting`.`install_intelligence`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`preload_recovery` to `dev_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery` LIKE `hive_metastore`.`lakehouse_reporting`.`preload_recovery` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`preload_recovery` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery` instead of `hive_metastore`.`lakehouse_reporting`.`preload_recovery`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` to `dev_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log` LIKE `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log` instead of `hive_metastore`.`lakehouse_reporting`.`preload_replay_log`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`revenue_shares_dimension` to `dev_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension` LIKE `hive_metastore`.`lakehouse_reporting`.`revenue_shares_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`revenue_shares_dimension` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`revenue_shares_dimension` instead of `hive_metastore`.`lakehouse_reporting`.`revenue_shares_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` to `dev_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report` LIKE `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report` instead of `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` to `dev_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`template_fact` to `dev_one_dt_datalake`.`lakehouse_reporting`.`template_fact`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`template_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`template_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`template_fact` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`template_fact`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`template_fact` instead of `hive_metastore`.`lakehouse_reporting`.`template_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`user_apps` to `dev_one_dt_datalake`.`lakehouse_reporting`.`user_apps`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`user_apps` LIKE `hive_metastore`.`lakehouse_reporting`.`user_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`user_apps` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`user_apps`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`user_apps` instead of `hive_metastore`.`lakehouse_reporting`.`user_apps`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`user_event_fact` to `dev_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact`
CREATE TABLE `dev_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`user_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`user_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`user_event_fact`');

# %%
-- Upgrade `hive_metastore`.`ostap`.`uevents_us_west_1` to `dev_one_dt_datalake`.`ostap`.`uevents_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`ostap`.`uevents_us_west_1` LIKE `hive_metastore`.`ostap`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`ostap`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`ostap`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`ostap`.`uevents_us_west_1` instead of `hive_metastore`.`ostap`.`uevents_us_west_1`');

# %%
-- Upgrade `hive_metastore`.`ppp`.`uevents_us_west_1` to `dev_one_dt_datalake`.`ppp`.`uevents_us_west_1`
CREATE TABLE `dev_one_dt_datalake`.`ppp`.`uevents_us_west_1` LIKE `hive_metastore`.`ppp`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`ppp`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`dev_one_dt_datalake`.`ppp`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `dev_one_dt_datalake`.`ppp`.`uevents_us_west_1` instead of `hive_metastore`.`ppp`.`uevents_us_west_1`');
