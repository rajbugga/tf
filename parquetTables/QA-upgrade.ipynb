# %%
-- Upgrade `hive_metastore`.`agp_aggregations`.`agp_data` to `stg_one_dt_datalake`.`agp_aggregations`.`agp_data`
CREATE TABLE `stg_one_dt_datalake`.`agp_aggregations`.`agp_data` LIKE `hive_metastore`.`agp_aggregations`.`agp_data` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`agp_aggregations`.`agp_data`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`agp_aggregations`.`agp_data` instead of `hive_metastore`.`agp_aggregations`.`agp_data`');

-- Upgrade `hive_metastore`.`agp_aggregations`.`agp_data_bkp` to `stg_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp`
CREATE TABLE `stg_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp` LIKE `hive_metastore`.`agp_aggregations`.`agp_data_bkp` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_data_bkp` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`agp_aggregations`.`agp_data_bkp` instead of `hive_metastore`.`agp_aggregations`.`agp_data_bkp`');

-- Upgrade `hive_metastore`.`agp_aggregations`.`agp_mapping` to `stg_one_dt_datalake`.`agp_aggregations`.`agp_mapping`
CREATE TABLE `stg_one_dt_datalake`.`agp_aggregations`.`agp_mapping` LIKE `hive_metastore`.`agp_aggregations`.`agp_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`agp_mapping` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`agp_aggregations`.`agp_mapping`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`agp_aggregations`.`agp_mapping` instead of `hive_metastore`.`agp_aggregations`.`agp_mapping`');

-- Upgrade `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` to `stg_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping`
CREATE TABLE `stg_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping` LIKE `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`agp_aggregations`.`one_dt_campaign_mapping` instead of `hive_metastore`.`agp_aggregations`.`one_dt_campaign_mapping`');

# %%
-- Upgrade `hive_metastore`.`fyber_bi`.`app_apps_daily` to `stg_one_dt_datalake`.`fyber_bi`.`app_apps_daily`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`app_apps_daily` LIKE `hive_metastore`.`fyber_bi`.`app_apps_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_apps_daily` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`app_apps_daily`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`app_apps_daily` instead of `hive_metastore`.`fyber_bi`.`app_apps_daily`');

-- Upgrade `hive_metastore`.`fyber_bi`.`app_apps_monthly` to `stg_one_dt_datalake`.`fyber_bi`.`app_apps_monthly`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`app_apps_monthly` LIKE `hive_metastore`.`fyber_bi`.`app_apps_monthly` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_apps_monthly` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`app_apps_monthly`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`app_apps_monthly` instead of `hive_metastore`.`fyber_bi`.`app_apps_monthly`');

-- Upgrade `hive_metastore`.`fyber_bi`.`app_fraud_data` to `stg_one_dt_datalake`.`fyber_bi`.`app_fraud_data`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`app_fraud_data` LIKE `hive_metastore`.`fyber_bi`.`app_fraud_data` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`app_fraud_data` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`app_fraud_data`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`app_fraud_data` instead of `hive_metastore`.`fyber_bi`.`app_fraud_data`');

-- Upgrade `hive_metastore`.`fyber_bi`.`archive` to `stg_one_dt_datalake`.`fyber_bi`.`archive`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`archive` LIKE `hive_metastore`.`fyber_bi`.`archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`archive` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`archive`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`archive` instead of `hive_metastore`.`fyber_bi`.`archive`');

-- Upgrade `hive_metastore`.`fyber_bi`.`fyberdaily` to `stg_one_dt_datalake`.`fyber_bi`.`fyberdaily`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`fyberdaily` LIKE `hive_metastore`.`fyber_bi`.`fyberdaily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`fyberdaily` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`fyberdaily`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`fyberdaily` instead of `hive_metastore`.`fyber_bi`.`fyberdaily`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_demand_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_demand_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_demand_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_demand_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_demand_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_demand_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_demand_goals` instead of `hive_metastore`.`fyber_bi`.`gls_demand_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_demand_managers_goals` instead of `hive_metastore`.`fyber_bi`.`gls_demand_managers_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_personal_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_personal_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_personal_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_personal_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_personal_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_personal_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_personal_goals` instead of `hive_metastore`.`fyber_bi`.`gls_personal_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_supply_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_supply_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_goals` instead of `hive_metastore`.`fyber_bi`.`gls_supply_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_managers_goals` instead of `hive_metastore`.`fyber_bi`.`gls_supply_managers_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_supply_pods_goals` instead of `hive_metastore`.`fyber_bi`.`gls_supply_pods_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_vps_demand_goals` instead of `hive_metastore`.`fyber_bi`.`gls_vps_demand_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` to `stg_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals` LIKE `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`gls_vps_supply_goals` instead of `hive_metastore`.`fyber_bi`.`gls_vps_supply_goals`');

-- Upgrade `hive_metastore`.`fyber_bi`.`med_mediation_daily` to `stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily` LIKE `hive_metastore`.`fyber_bi`.`med_mediation_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`med_mediation_daily` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily` instead of `hive_metastore`.`fyber_bi`.`med_mediation_daily`');

-- Upgrade `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` to `stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive` LIKE `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`med_mediation_daily_archive` instead of `hive_metastore`.`fyber_bi`.`med_mediation_daily_archive`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_fairbid` to `stg_one_dt_datalake`.`fyber_bi`.`prd_fairbid`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`prd_fairbid` LIKE `hive_metastore`.`fyber_bi`.`prd_fairbid` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_fairbid` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`prd_fairbid`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`prd_fairbid` instead of `hive_metastore`.`fyber_bi`.`prd_fairbid`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` to `stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand` LIKE `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_marketplacedemand` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacedemand` instead of `hive_metastore`.`fyber_bi`.`prd_marketplacedemand`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` to `stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply` LIKE `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_marketplacesupply` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`prd_marketplacesupply` instead of `hive_metastore`.`fyber_bi`.`prd_marketplacesupply`');

-- Upgrade `hive_metastore`.`fyber_bi`.`prd_offerwall` to `stg_one_dt_datalake`.`fyber_bi`.`prd_offerwall`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi`.`prd_offerwall` LIKE `hive_metastore`.`fyber_bi`.`prd_offerwall` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi`.`prd_offerwall` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi`.`prd_offerwall`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi`.`prd_offerwall` instead of `hive_metastore`.`fyber_bi`.`prd_offerwall`');

# %%
-- Upgrade `hive_metastore`.`fyber_bi_utils`.`ad_formats` to `stg_one_dt_datalake`.`fyber_bi_utils`.`ad_formats`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`ad_formats` LIKE `hive_metastore`.`fyber_bi_utils`.`ad_formats` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`ad_formats` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`ad_formats`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`ad_formats` instead of `hive_metastore`.`fyber_bi_utils`.`ad_formats`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`creative_types` to `stg_one_dt_datalake`.`fyber_bi_utils`.`creative_types`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`creative_types` LIKE `hive_metastore`.`fyber_bi_utils`.`creative_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`creative_types` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`creative_types`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`creative_types` instead of `hive_metastore`.`fyber_bi_utils`.`creative_types`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`dates` to `stg_one_dt_datalake`.`fyber_bi_utils`.`dates`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`dates` LIKE `hive_metastore`.`fyber_bi_utils`.`dates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`dates` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`dates`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`dates` instead of `hive_metastore`.`fyber_bi_utils`.`dates`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` to `stg_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities` LIKE `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`demand_opportunities` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`demand_opportunities` instead of `hive_metastore`.`fyber_bi_utils`.`demand_opportunities`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`employee_list` to `stg_one_dt_datalake`.`fyber_bi_utils`.`employee_list`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`employee_list` LIKE `hive_metastore`.`fyber_bi_utils`.`employee_list` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`employee_list` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`employee_list`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`employee_list` instead of `hive_metastore`.`fyber_bi_utils`.`employee_list`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` to `stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` LIKE `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping` instead of `hive_metastore`.`fyber_bi_utils`.`med_mediation_adnetwork_mapping`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` to `stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map` LIKE `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`med_mediation_map` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`med_mediation_map` instead of `hive_metastore`.`fyber_bi_utils`.`med_mediation_map`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` to `stg_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats` LIKE `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`new_ad_formats` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`new_ad_formats` instead of `hive_metastore`.`fyber_bi_utils`.`new_ad_formats`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`placement_types` to `stg_one_dt_datalake`.`fyber_bi_utils`.`placement_types`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`placement_types` LIKE `hive_metastore`.`fyber_bi_utils`.`placement_types` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`placement_types` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`placement_types`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`placement_types` instead of `hive_metastore`.`fyber_bi_utils`.`placement_types`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` to `stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand` LIKE `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypedemand` instead of `hive_metastore`.`fyber_bi_utils`.`revenuetypedemand`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` to `stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply` LIKE `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`revenuetypesupply` instead of `hive_metastore`.`fyber_bi_utils`.`revenuetypesupply`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`sf_demand` to `stg_one_dt_datalake`.`fyber_bi_utils`.`sf_demand`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`sf_demand` LIKE `hive_metastore`.`fyber_bi_utils`.`sf_demand` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`sf_demand` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`sf_demand`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`sf_demand` instead of `hive_metastore`.`fyber_bi_utils`.`sf_demand`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`sf_supply` to `stg_one_dt_datalake`.`fyber_bi_utils`.`sf_supply`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`sf_supply` LIKE `hive_metastore`.`fyber_bi_utils`.`sf_supply` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`sf_supply` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`sf_supply`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`sf_supply` instead of `hive_metastore`.`fyber_bi_utils`.`sf_supply`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` to `stg_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation` LIKE `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`start_date_mediation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`start_date_mediation` instead of `hive_metastore`.`fyber_bi_utils`.`start_date_mediation`');

-- Upgrade `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` to `stg_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities`
CREATE TABLE `stg_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities` LIKE `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_bi_utils`.`supply_opportunities` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_bi_utils`.`supply_opportunities` instead of `hive_metastore`.`fyber_bi_utils`.`supply_opportunities`');

# %%
-- Upgrade `hive_metastore`.`fyber_billing`.`marketplace` to `stg_one_dt_datalake`.`fyber_billing`.`marketplace`
CREATE TABLE `stg_one_dt_datalake`.`fyber_billing`.`marketplace` LIKE `hive_metastore`.`fyber_billing`.`marketplace` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`marketplace` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_billing`.`marketplace`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_billing`.`marketplace` instead of `hive_metastore`.`fyber_billing`.`marketplace`');

-- Upgrade `hive_metastore`.`fyber_billing`.`mpl_archive_v2` to `stg_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2`
CREATE TABLE `stg_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2` LIKE `hive_metastore`.`fyber_billing`.`mpl_archive_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`mpl_archive_v2` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_billing`.`mpl_archive_v2` instead of `hive_metastore`.`fyber_billing`.`mpl_archive_v2`');

-- Upgrade `hive_metastore`.`fyber_billing`.`offerwall` to `stg_one_dt_datalake`.`fyber_billing`.`offerwall`
CREATE TABLE `stg_one_dt_datalake`.`fyber_billing`.`offerwall` LIKE `hive_metastore`.`fyber_billing`.`offerwall` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`offerwall` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_billing`.`offerwall`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_billing`.`offerwall` instead of `hive_metastore`.`fyber_billing`.`offerwall`');

-- Upgrade `hive_metastore`.`fyber_billing`.`ofw_archive_v2` to `stg_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2`
CREATE TABLE `stg_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2` LIKE `hive_metastore`.`fyber_billing`.`ofw_archive_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`fyber_billing`.`ofw_archive_v2` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`fyber_billing`.`ofw_archive_v2` instead of `hive_metastore`.`fyber_billing`.`ofw_archive_v2`');

# %%
-- Upgrade `hive_metastore`.`lakehouse`.`aaid_daily` to `stg_one_dt_datalake`.`lakehouse`.`aaid_daily`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`aaid_daily` LIKE `hive_metastore`.`lakehouse`.`aaid_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`aaid_daily` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`aaid_daily`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`aaid_daily` instead of `hive_metastore`.`lakehouse`.`aaid_daily`');

-- Upgrade `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` to `stg_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa` LIKE `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`aggregate_partial_payloads_qa` instead of `hive_metastore`.`lakehouse`.`aggregate_partial_payloads_qa`');

-- Upgrade `hive_metastore`.`lakehouse`.`app_dimension` to `stg_one_dt_datalake`.`lakehouse`.`app_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`app_dimension` LIKE `hive_metastore`.`lakehouse`.`app_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`app_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`app_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`app_dimension` instead of `hive_metastore`.`lakehouse`.`app_dimension`');

-- Upgrade `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` to `stg_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaigndownload` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`audgraph_campaigndownload` instead of `hive_metastore`.`lakehouse`.`audgraph_campaigndownload`');

-- Upgrade `hive_metastore`.`lakehouse`.`audgraph_campaignflow` to `stg_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow` LIKE `hive_metastore`.`lakehouse`.`audgraph_campaignflow` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audgraph_campaignflow` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`audgraph_campaignflow` instead of `hive_metastore`.`lakehouse`.`audgraph_campaignflow`');

-- Upgrade `hive_metastore`.`lakehouse`.`audience_facets_cache` to `stg_one_dt_datalake`.`lakehouse`.`audience_facets_cache`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`audience_facets_cache` LIKE `hive_metastore`.`lakehouse`.`audience_facets_cache` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`audience_facets_cache` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`audience_facets_cache`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`audience_facets_cache` instead of `hive_metastore`.`lakehouse`.`audience_facets_cache`');

-- Upgrade `hive_metastore`.`lakehouse`.`bidrate` to `stg_one_dt_datalake`.`lakehouse`.`bidrate`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bidrate` LIKE `hive_metastore`.`lakehouse`.`bidrate` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bidrate` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bidrate`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bidrate` instead of `hive_metastore`.`lakehouse`.`bidrate`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_campaign` to `stg_one_dt_datalake`.`lakehouse`.`bronze_campaign`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_campaign` LIKE `hive_metastore`.`lakehouse`.`bronze_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_campaign` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_campaign`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_campaign` instead of `hive_metastore`.`lakehouse`.`bronze_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_campaign_test` to `stg_one_dt_datalake`.`lakehouse`.`bronze_campaign_test`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_campaign_test` LIKE `hive_metastore`.`lakehouse`.`bronze_campaign_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_campaign_test` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_campaign_test`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_campaign_test` instead of `hive_metastore`.`lakehouse`.`bronze_campaign_test`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_mcs_signal` to `stg_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal` LIKE `hive_metastore`.`lakehouse`.`bronze_mcs_signal` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_mcs_signal` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_mcs_signal` instead of `hive_metastore`.`lakehouse`.`bronze_mcs_signal`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_notification` to `stg_one_dt_datalake`.`lakehouse`.`bronze_notification`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_notification` LIKE `hive_metastore`.`lakehouse`.`bronze_notification` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_notification` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_notification`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_notification` instead of `hive_metastore`.`lakehouse`.`bronze_notification`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_pie` to `stg_one_dt_datalake`.`lakehouse`.`bronze_pie`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_pie` LIKE `hive_metastore`.`lakehouse`.`bronze_pie` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_pie` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_pie`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_pie` instead of `hive_metastore`.`lakehouse`.`bronze_pie`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_preloads_all` to `stg_one_dt_datalake`.`lakehouse`.`bronze_preloads_all`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_preloads_all` LIKE `hive_metastore`.`lakehouse`.`bronze_preloads_all` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_preloads_all` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_preloads_all`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_preloads_all` instead of `hive_metastore`.`lakehouse`.`bronze_preloads_all`');

-- Upgrade `hive_metastore`.`lakehouse`.`bronze_sti_campaign` to `stg_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign` LIKE `hive_metastore`.`lakehouse`.`bronze_sti_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`bronze_sti_campaign` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`bronze_sti_campaign` instead of `hive_metastore`.`lakehouse`.`bronze_sti_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`campaign_postback` to `stg_one_dt_datalake`.`lakehouse`.`campaign_postback`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`campaign_postback` LIKE `hive_metastore`.`lakehouse`.`campaign_postback` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`campaign_postback` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`campaign_postback`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`campaign_postback` instead of `hive_metastore`.`lakehouse`.`campaign_postback`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_dimension_us_west_1` instead of `hive_metastore`.`lakehouse`.`carrier_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1` instead of `hive_metastore`.`lakehouse`.`carrier_mcc_mnc_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`credit_events` to `stg_one_dt_datalake`.`lakehouse`.`credit_events`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`credit_events` LIKE `hive_metastore`.`lakehouse`.`credit_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`credit_events` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`credit_events`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`credit_events` instead of `hive_metastore`.`lakehouse`.`credit_events`');

-- Upgrade `hive_metastore`.`lakehouse`.`device_profile` to `stg_one_dt_datalake`.`lakehouse`.`device_profile`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`device_profile` LIKE `hive_metastore`.`lakehouse`.`device_profile` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`device_profile` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`device_profile`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`device_profile` instead of `hive_metastore`.`lakehouse`.`device_profile`');

-- Upgrade `hive_metastore`.`lakehouse`.`device_profile_test` to `stg_one_dt_datalake`.`lakehouse`.`device_profile_test`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`device_profile_test` LIKE `hive_metastore`.`lakehouse`.`device_profile_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`device_profile_test` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`device_profile_test`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`device_profile_test` instead of `hive_metastore`.`lakehouse`.`device_profile_test`');

-- Upgrade `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` to `stg_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log` LIKE `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`dsp_impression_matching_log` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`dsp_impression_matching_log` instead of `hive_metastore`.`lakehouse`.`dsp_impression_matching_log`');

-- Upgrade `hive_metastore`.`lakehouse`.`invalid_pie_userevent` to `stg_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent` LIKE `hive_metastore`.`lakehouse`.`invalid_pie_userevent` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`invalid_pie_userevent` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`invalid_pie_userevent` instead of `hive_metastore`.`lakehouse`.`invalid_pie_userevent`');

-- Upgrade `hive_metastore`.`lakehouse`.`invalid_silver_events` to `stg_one_dt_datalake`.`lakehouse`.`invalid_silver_events`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`invalid_silver_events` LIKE `hive_metastore`.`lakehouse`.`invalid_silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`invalid_silver_events` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`invalid_silver_events`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`invalid_silver_events` instead of `hive_metastore`.`lakehouse`.`invalid_silver_events`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`mcc_mnc_dimension_us_west_1` instead of `hive_metastore`.`lakehouse`.`mcc_mnc_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`partial_payloads_daily` to `stg_one_dt_datalake`.`lakehouse`.`partial_payloads_daily`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`partial_payloads_daily` LIKE `hive_metastore`.`lakehouse`.`partial_payloads_daily` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`partial_payloads_daily` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`partial_payloads_daily`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`partial_payloads_daily` instead of `hive_metastore`.`lakehouse`.`partial_payloads_daily`');

-- Upgrade `hive_metastore`.`lakehouse`.`referrer_cache_v2` to `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v2`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v2` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v2` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v2`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v2` instead of `hive_metastore`.`lakehouse`.`referrer_cache_v2`');

-- Upgrade `hive_metastore`.`lakehouse`.`referrer_cache_v4` to `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v4`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v4` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v4` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v4` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v4`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v4` instead of `hive_metastore`.`lakehouse`.`referrer_cache_v4`');

-- Upgrade `hive_metastore`.`lakehouse`.`referrer_cache_v5` to `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v5`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v5` LIKE `hive_metastore`.`lakehouse`.`referrer_cache_v5` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`referrer_cache_v5` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v5`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`referrer_cache_v5` instead of `hive_metastore`.`lakehouse`.`referrer_cache_v5`');

-- Upgrade `hive_metastore`.`lakehouse`.`sequestered_campaign` to `stg_one_dt_datalake`.`lakehouse`.`sequestered_campaign`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`sequestered_campaign` LIKE `hive_metastore`.`lakehouse`.`sequestered_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`sequestered_campaign` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`sequestered_campaign`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`sequestered_campaign` instead of `hive_metastore`.`lakehouse`.`sequestered_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`silver_events` to `stg_one_dt_datalake`.`lakehouse`.`silver_events`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`silver_events` LIKE `hive_metastore`.`lakehouse`.`silver_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_events` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`silver_events`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`silver_events` instead of `hive_metastore`.`lakehouse`.`silver_events`');

-- Upgrade `hive_metastore`.`lakehouse`.`silver_sti_campaign` to `stg_one_dt_datalake`.`lakehouse`.`silver_sti_campaign`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`silver_sti_campaign` LIKE `hive_metastore`.`lakehouse`.`silver_sti_campaign` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`silver_sti_campaign` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`silver_sti_campaign`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`silver_sti_campaign` instead of `hive_metastore`.`lakehouse`.`silver_sti_campaign`');

-- Upgrade `hive_metastore`.`lakehouse`.`tripledot_dt_activity` to `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_activity` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_activity` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_activity` instead of `hive_metastore`.`lakehouse`.`tripledot_dt_activity`');

-- Upgrade `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` to `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_key_metrics` instead of `hive_metastore`.`lakehouse`.`tripledot_dt_key_metrics`');

-- Upgrade `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` to `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue` LIKE `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`tripledot_dt_revenue` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`tripledot_dt_revenue` instead of `hive_metastore`.`lakehouse`.`tripledot_dt_revenue`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_ap_south_1` to `stg_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1` LIKE `hive_metastore`.`lakehouse`.`uevents_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_ap_south_1` instead of `hive_metastore`.`lakehouse`.`uevents_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_eu_central_1` to `stg_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1` LIKE `hive_metastore`.`lakehouse`.`uevents_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_eu_central_1` instead of `hive_metastore`.`lakehouse`.`uevents_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_postbackevents` to `stg_one_dt_datalake`.`lakehouse`.`uevents_postbackevents`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_postbackevents` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackevents` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_postbackevents`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_postbackevents` instead of `hive_metastore`.`lakehouse`.`uevents_postbackevents`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_postbackfailures` to `stg_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures` LIKE `hive_metastore`.`lakehouse`.`uevents_postbackfailures` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_postbackfailures` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_postbackfailures` instead of `hive_metastore`.`lakehouse`.`uevents_postbackfailures`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_reclickevents` to `stg_one_dt_datalake`.`lakehouse`.`uevents_reclickevents`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_reclickevents` LIKE `hive_metastore`.`lakehouse`.`uevents_reclickevents` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_reclickevents` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_reclickevents`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_reclickevents` instead of `hive_metastore`.`lakehouse`.`uevents_reclickevents`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_sa_east_1` to `stg_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1` LIKE `hive_metastore`.`lakehouse`.`uevents_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_sa_east_1` instead of `hive_metastore`.`lakehouse`.`uevents_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse`.`uevents_us_west_1` to `stg_one_dt_datalake`.`lakehouse`.`uevents_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse`.`uevents_us_west_1` LIKE `hive_metastore`.`lakehouse`.`uevents_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse`.`uevents_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse`.`uevents_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse`.`uevents_us_west_1` instead of `hive_metastore`.`lakehouse`.`uevents_us_west_1`');

# %%
-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_integration_error_log` instead of `hive_metastore`.`lakehouse_dimensions`.`ad_integration_error_log`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`ad_template_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`ad_template_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`app_versions` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`app_versions`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`app_versions` LIKE `hive_metastore`.`lakehouse_dimensions`.`app_versions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`app_versions` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`app_versions`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`app_versions` instead of `hive_metastore`.`lakehouse_dimensions`.`app_versions`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`application_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`application_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`audience_definition` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition` LIKE `hive_metastore`.`lakehouse_dimensions`.`audience_definition` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`audience_definition` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`audience_definition` instead of `hive_metastore`.`lakehouse_dimensions`.`audience_definition`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`billing_type_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`billing_type_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_dimension_stg` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_dimension_stg`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_budget_v2` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_budget_v2`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_country_region_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_country_region_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_fulfillment_type_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_lookup_aggregation` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_lookup_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_product_flow_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_product_flow_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_activity_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_activity_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_device_fact` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_device_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_device_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_device_fact` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_device_fact`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_download_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_download_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_download_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_download_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_download_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_provider_flow_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_provider_flow_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_availability_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_site_availability_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`campaign_site_override_lookup_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`carrier` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier` instead of `hive_metastore`.`lakehouse_dimensions`.`carrier`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc` LIKE `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`carrier_mcc_mnc` instead of `hive_metastore`.`lakehouse_dimensions`.`carrier_mcc_mnc`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`category_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`category_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`category_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`category_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`category_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`client` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`client`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`client` LIKE `hive_metastore`.`lakehouse_dimensions`.`client` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`client`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`client` instead of `hive_metastore`.`lakehouse_dimensions`.`client`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`client_config` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`client_config`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`client_config` LIKE `hive_metastore`.`lakehouse_dimensions`.`client_config` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client_config` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`client_config`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`client_config` instead of `hive_metastore`.`lakehouse_dimensions`.`client_config`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`client_tracking` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking` LIKE `hive_metastore`.`lakehouse_dimensions`.`client_tracking` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`client_tracking` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`client_tracking` instead of `hive_metastore`.`lakehouse_dimensions`.`client_tracking`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`country_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`country_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`country_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`country_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`country_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`creative_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`creative_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`creative_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`device_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_os_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_os_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_slot` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_slot`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_slot` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_slot` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_slot` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_slot`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_slot` instead of `hive_metastore`.`lakehouse_dimensions`.`device_slot`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`device_type_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`device_type_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`discovery_notifications_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`discovery_notifications_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin` LIKE `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`dtid_product_origin` instead of `hive_metastore`.`lakehouse_dimensions`.`dtid_product_origin`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows` LIKE `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`interval_wizard_windows` instead of `hive_metastore`.`lakehouse_dimensions`.`interval_wizard_windows`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`location_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`location_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`location_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`location_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`location_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_ap_south_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_eu_central_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_sa_east_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` LIKE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1` instead of `hive_metastore`.`lakehouse_dimensions`.`mcc_mnc_dimension_us_west_1`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind` LIKE `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`network_partner_kind` instead of `hive_metastore`.`lakehouse_dimensions`.`network_partner_kind`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`notifications_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`notifications_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`partner_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`partner_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`partner_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`placement_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`placement_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`placement_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`platform_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`platform_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`platform_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`ppd_category` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category` LIKE `hive_metastore`.`lakehouse_dimensions`.`ppd_category` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`ppd_category` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`ppd_category` instead of `hive_metastore`.`lakehouse_dimensions`.`ppd_category`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`priority_campaign_set_type_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`process` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`process`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`process` LIKE `hive_metastore`.`lakehouse_dimensions`.`process` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`process`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`process` instead of `hive_metastore`.`lakehouse_dimensions`.`process`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs` LIKE `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`process_fdrs` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`process_fdrs` instead of `hive_metastore`.`lakehouse_dimensions`.`process_fdrs`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup` LIKE `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`product_flow_lookup` instead of `hive_metastore`.`lakehouse_dimensions`.`product_flow_lookup`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`property_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`property_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`property_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`property_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`property_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`push_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`push_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`push_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`push_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`push_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`push_success_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`push_success_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`push_success_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`push_success_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`push_success_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`site_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`site_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`site_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`site_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`site_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`site_priority_campaigns_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`site_priority_campaigns_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test` LIKE `hive_metastore`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test` instead of `hive_metastore`.`lakehouse_dimensions`.`sub_partner_dimension_vw_test`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`subpartner_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`subpartner_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`subsite_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`subsite_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`targets_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`targets_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`targets_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`transactions` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions` LIKE `hive_metastore`.`lakehouse_dimensions`.`transactions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`transactions` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions` instead of `hive_metastore`.`lakehouse_dimensions`.`transactions`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`transactions_events` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events` LIKE `hive_metastore`.`lakehouse_dimensions`.`transactions_events` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`transactions_events` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`transactions_events` instead of `hive_metastore`.`lakehouse_dimensions`.`transactions_events`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension` LIKE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension` instead of `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension`');

-- Upgrade `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension_vw_test` to `stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension_vw_test`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension_vw_test` LIKE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension_vw_test` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension_vw_test` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension_vw_test`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_dimensions`.`vendor_dimension_vw_test` instead of `hive_metastore`.`lakehouse_dimensions`.`vendor_dimension_vw_test`');

# %%
-- Upgrade `hive_metastore`.`lakehouse_reporting`.`active_device_base` to `stg_one_dt_datalake`.`lakehouse_reporting`.`active_device_base`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`active_device_base` LIKE `hive_metastore`.`lakehouse_reporting`.`active_device_base` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`active_device_base` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`active_device_base`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`active_device_base` instead of `hive_metastore`.`lakehouse_reporting`.`active_device_base`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`ad_integration_placements` to `stg_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements` LIKE `hive_metastore`.`lakehouse_reporting`.`ad_integration_placements` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`ad_integration_placements` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`ad_integration_placements` instead of `hive_metastore`.`lakehouse_reporting`.`ad_integration_placements`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`ad_unit_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`ad_unit_event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`advertiser_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`advertiser_fact` instead of `hive_metastore`.`lakehouse_reporting`.`advertiser_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_pre_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_health_report` instead of `hive_metastore`.`lakehouse_reporting`.`applist_campaign_health_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_campaign_performance` instead of `hive_metastore`.`lakehouse_reporting`.`applist_campaign_performance`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact` instead of `hive_metastore`.`lakehouse_reporting`.`applist_carrier_campaign_health_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion` instead of `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_device_conversion_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`applist_device_conversion_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_terms_conditions` instead of `hive_metastore`.`lakehouse_reporting`.`applist_terms_conditions`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe` instead of `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`applist_unsubscribe_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`applist_unsubscribe_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` to `stg_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads` LIKE `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`appwidget_getads` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`appwidget_getads` instead of `hive_metastore`.`lakehouse_reporting`.`appwidget_getads`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity` LIKE `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audience_graph_device_activity` instead of `hive_metastore`.`lakehouse_reporting`.`audience_graph_device_activity`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_advertiser_campaign_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_budget_pool_setup_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_discovery_notification_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_setup_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_setup_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_setup_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_setup_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_setup_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_update_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_update_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_update_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_campaign_update_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_campaign_update_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_site_optimization_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_site_optimization_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_site_optimization_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_site_optimization_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_site_optimization_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`audittrail_target_group_event` to `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event` LIKE `hive_metastore`.`lakehouse_reporting`.`audittrail_target_group_event` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`audittrail_target_group_event` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`audittrail_target_group_event` instead of `hive_metastore`.`lakehouse_reporting`.`audittrail_target_group_event`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`credit_event_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`credit_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`credit_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`credit_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`credit_event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`dt_device_report` to `stg_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report` LIKE `hive_metastore`.`lakehouse_reporting`.`dt_device_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dt_device_report` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`dt_device_report` instead of `hive_metastore`.`lakehouse_reporting`.`dt_device_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`dt_samsung_regions` to `stg_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions` LIKE `hive_metastore`.`lakehouse_reporting`.`dt_samsung_regions` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`dt_samsung_regions` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`dt_samsung_regions` instead of `hive_metastore`.`lakehouse_reporting`.`dt_samsung_regions`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`event_data_blended` to `stg_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended` LIKE `hive_metastore`.`lakehouse_reporting`.`event_data_blended` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_data_blended` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`event_data_blended` instead of `hive_metastore`.`lakehouse_reporting`.`event_data_blended`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`event_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`event_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`event_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`event_lta` to `stg_one_dt_datalake`.`lakehouse_reporting`.`event_lta`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`event_lta` LIKE `hive_metastore`.`lakehouse_reporting`.`event_lta` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`event_lta` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`event_lta`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`event_lta` instead of `hive_metastore`.`lakehouse_reporting`.`event_lta`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`exchange_rates` to `stg_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates` LIKE `hive_metastore`.`lakehouse_reporting`.`exchange_rates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`exchange_rates` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`exchange_rates` instead of `hive_metastore`.`lakehouse_reporting`.`exchange_rates`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`install_intelligence` to `stg_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence` LIKE `hive_metastore`.`lakehouse_reporting`.`install_intelligence` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`install_intelligence` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`install_intelligence` instead of `hive_metastore`.`lakehouse_reporting`.`install_intelligence`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`lyft_notification_control` to `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_control` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_control` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_control` instead of `hive_metastore`.`lakehouse_reporting`.`lyft_notification_control`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`lyft_notification_treatment` to `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_treatment` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_notification_treatment` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_notification_treatment` instead of `hive_metastore`.`lakehouse_reporting`.`lyft_notification_treatment`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`lyft_silent_control` to `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_control` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_control` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_control` instead of `hive_metastore`.`lakehouse_reporting`.`lyft_silent_control`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`lyft_silent_treatment` to `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment` LIKE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_treatment` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`lyft_silent_treatment` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`lyft_silent_treatment` instead of `hive_metastore`.`lakehouse_reporting`.`lyft_silent_treatment`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`motorola_export` to `stg_one_dt_datalake`.`lakehouse_reporting`.`motorola_export`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`motorola_export` LIKE `hive_metastore`.`lakehouse_reporting`.`motorola_export` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`motorola_export` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`motorola_export`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`motorola_export` instead of `hive_metastore`.`lakehouse_reporting`.`motorola_export`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`notification_conversion_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_conversion_report` to `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_conversion_report` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_conversion_report` instead of `hive_metastore`.`lakehouse_reporting`.`notification_conversion_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_health_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`notification_health_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`notification_revenue_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`notification_revenue_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`partner_download_rates` to `stg_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates` LIKE `hive_metastore`.`lakehouse_reporting`.`partner_download_rates` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`partner_download_rates` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`partner_download_rates` instead of `hive_metastore`.`lakehouse_reporting`.`partner_download_rates`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`partner_exclude` to `stg_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude` LIKE `hive_metastore`.`lakehouse_reporting`.`partner_exclude` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`partner_exclude` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`partner_exclude` instead of `hive_metastore`.`lakehouse_reporting`.`partner_exclude`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`pia_conversion_event_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`pia_conversion_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`pia_conversion_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`pia_conversion_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`pia_conversion_event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`pia_event_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`pia_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`pia_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`pia_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`pia_event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`preload_recovery` to `stg_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery` LIKE `hive_metastore`.`lakehouse_reporting`.`preload_recovery` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`preload_recovery` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`preload_recovery` instead of `hive_metastore`.`lakehouse_reporting`.`preload_recovery`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` to `stg_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log` LIKE `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`preload_replay_log` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`preload_replay_log` instead of `hive_metastore`.`lakehouse_reporting`.`preload_replay_log`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` to `stg_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report` LIKE `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`source_event_fact_report` instead of `hive_metastore`.`lakehouse_reporting`.`source_event_fact_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` to `stg_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` LIKE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation` instead of `hive_metastore`.`lakehouse_reporting`.`sti_event_reporting_uevents_aggregation`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`template_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`template_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`template_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`template_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`template_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`template_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`template_fact` instead of `hive_metastore`.`lakehouse_reporting`.`template_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`tripledot_dt_report` to `stg_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report` LIKE `hive_metastore`.`lakehouse_reporting`.`tripledot_dt_report` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`tripledot_dt_report` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`tripledot_dt_report` instead of `hive_metastore`.`lakehouse_reporting`.`tripledot_dt_report`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`user_apps` to `stg_one_dt_datalake`.`lakehouse_reporting`.`user_apps`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`user_apps` LIKE `hive_metastore`.`lakehouse_reporting`.`user_apps` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`user_apps` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`user_apps`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`user_apps` instead of `hive_metastore`.`lakehouse_reporting`.`user_apps`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`user_event_fact` to `stg_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact` LIKE `hive_metastore`.`lakehouse_reporting`.`user_event_fact` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`user_event_fact` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`user_event_fact` instead of `hive_metastore`.`lakehouse_reporting`.`user_event_fact`');

-- Upgrade `hive_metastore`.`lakehouse_reporting`.`vzw_imei_data_library` to `stg_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library`
CREATE TABLE `stg_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library` LIKE `hive_metastore`.`lakehouse_reporting`.`vzw_imei_data_library` COPY LOCATION;
ALTER TABLE `hive_metastore`.`lakehouse_reporting`.`vzw_imei_data_library` SET TBLPROPERTIES ('upgraded_to' = '`stg_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library`', 'comment' = 'This table is deprecated. Please update to use `stg_one_dt_datalake`.`lakehouse_reporting`.`vzw_imei_data_library` instead of `hive_metastore`.`lakehouse_reporting`.`vzw_imei_data_library`');
